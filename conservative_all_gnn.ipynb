# %% [markdown]
# # 生成数据集

# %%
import sqlite3
import pandas as pd
import json

# 连接 SQLite 数据库
db_path = "latest.db"  # 替换为实际路径
conn = sqlite3.connect(db_path)

# 1. 筛选 BIOG_MAIN 中满足条件的 c_personid
query_biog_main = """
SELECT c_personid
FROM BIOG_MAIN
WHERE c_dy = 20
"""
biog_main = pd.read_sql(query_biog_main, conn)

# 2. 获取 ENTRY_DATA 中 c_personid 对应的 c_entry_code
query_entry_data = """
SELECT c_personid, c_entry_code
FROM ENTRY_DATA
"""
entry_data = pd.read_sql(query_entry_data, conn)

# 聚合 ENTRY_DATA 中同一 c_personid 的 c_entry_code
entry_data_agg = entry_data.groupby('c_personid')['c_entry_code'].agg(list).reset_index()

# 合并入仕信息
print(f"BIOG_MAIN 条数（原始）：{len(biog_main)}")
biog_main = biog_main.merge(entry_data_agg, on='c_personid', how='left')
print(f"BIOG_MAIN 条数（合并 ENTRY_DATA 后）：{len(biog_main)}")

# 填充缺失的 c_entry_code 为 -2，并转为整数类型
biog_main['c_entry_code'] = biog_main['c_entry_code'].apply(lambda x: x if isinstance(x, list) else [-2])

# 3. 获取 KIN_DATA 中 c_personid 对应的 c_kin_id 和 c_kin_code
query_kin_data = """
SELECT c_personid, c_kin_id, c_kin_code
FROM KIN_DATA
"""
kin_data = pd.read_sql(query_kin_data, conn)

# 合并家庭信息（保持多对一关系）
kin_data['c_kin_id'] = kin_data['c_kin_id'].fillna(-2).astype(int)
kin_data['c_kin_code'] = kin_data['c_kin_code'].fillna(-2).astype(int)

# 4. 获取 KINSHIP_CODES 中 c_kin_code 对应的 c_kin_pair1 和 c_kin_pair2
query_kinship_codes = """
SELECT c_kincode, c_kin_pair1, c_kin_pair2
FROM KINSHIP_CODES
"""
kinship_codes = pd.read_sql(query_kinship_codes, conn)

# 合并亲属关系信息
kinship_codes['c_kin_pair1'] = kinship_codes['c_kin_pair1'].fillna(-2).astype(int)
kinship_codes['c_kin_pair2'] = kinship_codes['c_kin_pair2'].fillna(-2).astype(int)

# 关闭数据库连接
conn.close()

# 5. 整合信息到 JSON 格式
result = []
for _, row in biog_main.iterrows():
    person_data = {
        "c_personid": int(row['c_personid']),
        "c_entry_code": row['c_entry_code'],  # 保持 c_entry_code 为列表形式
        "kinships": []
    }

    # 获取当前 c_personid 的家庭信息
    person_kin_data = kin_data[kin_data['c_personid'] == row['c_personid']]
    for _, kin_row in person_kin_data.iterrows():
        kin_code = int(kin_row['c_kin_code'])
        kin_info = {
            "c_kin_id": int(kin_row['c_kin_id']),
            "c_kin_code": kin_code,
            "c_kin_pair1": -2,
            "c_kin_pair2": -2
        }

        # 获取 c_kin_code 对应的亲属关系
        kinship_info = kinship_codes[kinship_codes['c_kincode'] == kin_code]
        if not kinship_info.empty:
            kin_info['c_kin_pair1'] = int(kinship_info.iloc[0]['c_kin_pair1'])
            kin_info['c_kin_pair2'] = int(kinship_info.iloc[0]['c_kin_pair2'])

        person_data["kinships"].append(kin_info)

    result.append(person_data)
# 6. 写入 JSON 文件
with open("conservative_all_data.json", "w", encoding="utf-8") as f:
    json.dump(result, f, ensure_ascii=False, indent=4)

print("JSON 文件生成成功：conservative_all_data.json")
# Out:
# BIOG_MAIN 条数（原始）：228527
# BIOG_MAIN 条数（合并 ENTRY_DATA 后）：228527
# JSON 文件生成成功：conservative_all_data.json

# %% [markdown]
# # 加载文件形成图结构

# %%
import json
import dgl
import torch

# 加载 JSON 文件
with open("conservative_all_data.json", "r", encoding="utf-8") as f:
    data = json.load(f)

# 统计 kinships 为空的节点数量
total_nodes = len(data)
data_with_kinships = [person for person in data if len(person.get("kinships", [])) > 0]
nodes_without_kinships = total_nodes - len(data_with_kinships)
proportion_without_kinships = nodes_without_kinships / total_nodes

print(f"Total nodes: {total_nodes}")
print(f"Nodes without kinships: {nodes_without_kinships}")
print(f"Proportion of nodes without kinships: {proportion_without_kinships:.2%}")

# 跳过 kinships 为空的观测
data = data_with_kinships

# 构建 node_id_map，确保所有 c_personid 和 c_kin_id 都被映射
node_ids = []         # 所有的 c_personid
kin_ids = set()      # 所有的 c_kin_id（去重）
node_labels = []     # 节点标签
entry_code_features = []   # 存储 c_entry_code 特征
kinship_count_features = []  # 存储 kinships 数量特征

# 遍历 JSON 数据，构建节点和边
for person in data:
    # 添加节点 ID
    node_ids.append(person["c_personid"])

    # 处理入仕标签：检查 c_entry_code 列表中是否有非负值
    c_entry_code = person["c_entry_code"]
    if any(code >= 0 for code in c_entry_code):  # 只要有一个非负值，就视为入仕
        node_labels.append(1)  # 入仕，标签为 1
    else:
        node_labels.append(0)  # 未入仕，标签为 0

    # 提取 c_entry_code 特征：如果有值，则选择第一个有效的（或者填充为 -2）
    entry_code_feature = c_entry_code[0] if c_entry_code else -2
    entry_code_features.append([entry_code_feature])

    # 计算 kinships 数量
    kinship_count_features.append([len(person.get("kinships", []))])

    # 添加 kin_ids
    for kinship in person.get("kinships", []):
        kin_ids.add(kinship["c_kin_id"])

# 构建 node_id_map，确保所有的 c_personid 和 c_kin_id 都在映射中
node_id_map = {nid: idx for idx, nid in enumerate(node_ids)}
kin_id_map = {kin_id: idx + len(node_id_map) for idx, kin_id in enumerate(kin_ids)}  # 确保 kin_id 从 node_id_map 后面开始

# 合并 node_id_map 和 kin_id_map
node_id_map.update(kin_id_map)

# 创建图
edges_src = []        # 边的起点
edges_dst = []        # 边的终点

# 遍历数据构建边
for person in data:
    for kinship in person.get("kinships", []):
        src_node = person["c_personid"]
        dst_node = kinship["c_kin_id"]

        # 仅添加有效的边
        if src_node in node_id_map and dst_node in node_id_map:
            edges_src.append(node_id_map[src_node])
            edges_dst.append(node_id_map[dst_node])

# 确保 `edges_src` 和 `edges_dst` 的长度一致
assert len(edges_src) == len(edges_dst), "Source and destination nodes' lengths do not match"

# 构建图（不添加自环）
g = dgl.graph((edges_src, edges_dst))

# 填充缺失的节点标签和特征，直到它们的数量与图的节点数一致
while len(node_labels) < g.num_nodes():
    node_labels.append(0)  # 填充为默认标签 0（未入仕）

while len(entry_code_features) < g.num_nodes():
    entry_code_features.append([-2])  # 填充为默认特征值 [-2]（无入仕信息）

while len(kinship_count_features) < g.num_nodes():
    kinship_count_features.append([0])  # 填充为默认特征值 0（无家庭关系）

# 设置节点标签和特征
g.ndata['label'] = torch.tensor(node_labels)  # 填充后的标签
g.ndata['entry_code_feat'] = torch.tensor(entry_code_features, dtype=torch.float)  # c_entry_code 特征
g.ndata['kinship_count_feat'] = torch.tensor(kinship_count_features, dtype=torch.float)  # kinships 数量特征

# 输出图的基本信息
print("图的节点数：", g.num_nodes())
print("图的边数：", g.num_edges())
print("c_entry_code 特征：", g.ndata['entry_code_feat'].shape)
print("kinships 数量特征：", g.ndata['kinship_count_feat'].shape)
print("节点标签：", g.ndata['label'].shape)
# Out:
# Total nodes: 23726
# Nodes without kinships: 22688
# Proportion of nodes without kinships: 95.63%
# 图的节点数： 3026
# 图的边数： 3017
# c_entry_code 特征： torch.Size([3026, 1])
# kinships 数量特征： torch.Size([3026, 1])
# 节点标签： torch.Size([3026])

# %%
import json
import dgl
import torch

# 加载 JSON 文件
with open("conservative_all_data.json", "r", encoding="utf-8") as f:
    data = json.load(f)

# 统计 kinships 为空的节点数量
total_nodes = len(data)
data_with_kinships = [person for person in data if len(person.get("kinships", [])) > 0]
nodes_without_kinships = total_nodes - len(data_with_kinships)
proportion_without_kinships = nodes_without_kinships / total_nodes

print(f"Total nodes: {total_nodes}")
print(f"Nodes without kinships: {nodes_without_kinships}")
print(f"Proportion of nodes without kinships: {proportion_without_kinships:.2%}")

# 跳过 kinships 为空的观测
data = data_with_kinships

# 构建 node_id_map，确保所有 c_personid 和 c_kin_id 都被映射
node_ids = []         # 所有的 c_personid
kin_ids = set()      # 所有的 c_kin_id（去重）
node_labels = []     # 节点标签
entry_code_features = []   # 存储 c_entry_code 特征
kinship_count_features = []  # 存储 kinships 数量特征

# 遍历 JSON 数据，构建节点和边
for person in data:
    # 添加节点 ID
    node_ids.append(person["c_personid"])

    # 处理入仕标签：检查 c_entry_code 列表中是否有非负值
    c_entry_code = person["c_entry_code"]
    if any(code >= 0 for code in c_entry_code):  # 只要有一个非负值，就视为入仕
        node_labels.append(1)  # 入仕，标签为 1
    else:
        node_labels.append(0)  # 未入仕，标签为 0

    # 提取 c_entry_code 特征：如果有值，则选择第一个有效的（或者填充为 -2）
    entry_code_feature = c_entry_code[0] if c_entry_code else -2
    entry_code_features.append([entry_code_feature])

    # 计算 kinships 数量
    kinship_count_features.append([len(person.get("kinships", []))])

    # 添加 kin_ids
    for kinship in person.get("kinships", []):
        kin_ids.add(kinship["c_kin_id"])

# 构建 node_id_map，确保所有的 c_personid 和 c_kin_id 都在映射中
node_id_map = {nid: idx for idx, nid in enumerate(node_ids)}
kin_id_map = {kin_id: idx + len(node_id_map) for idx, kin_id in enumerate(kin_ids)}  # 确保 kin_id 从 node_id_map 后面开始

# 合并 node_id_map 和 kin_id_map
node_id_map.update(kin_id_map)

# 创建图
edges_src = []        # 边的起点
edges_dst = []        # 边的终点

# 遍历数据构建边，并模拟无向图（双向边）
for person in data:
    for kinship in person.get("kinships", []):
        src_node = person["c_personid"]
        dst_node = kinship["c_kin_id"]

        # 仅添加有效的边
        if src_node in node_id_map and dst_node in node_id_map:
            edges_src.append(node_id_map[src_node])
            edges_dst.append(node_id_map[dst_node])

            # 添加反向边，模拟无向图
            edges_src.append(node_id_map[dst_node])
            edges_dst.append(node_id_map[src_node])

# 确保 `edges_src` 和 `edges_dst` 的长度一致
assert len(edges_src) == len(edges_dst), "Source and destination nodes' lengths do not match"

# 构建图
g = dgl.graph((edges_src, edges_dst))

# 填充缺失的节点标签和特征，直到它们的数量与图的节点数一致
while len(node_labels) < g.num_nodes():
    node_labels.append(0)  # 填充为默认标签 0（未入仕）

while len(entry_code_features) < g.num_nodes():
    entry_code_features.append([-2])  # 填充为默认特征值 [-2]（无入仕信息）

while len(kinship_count_features) < g.num_nodes():
    kinship_count_features.append([0])  # 填充为默认特征值 0（无家庭关系）

# 设置节点标签和特征
g.ndata['label'] = torch.tensor(node_labels)  # 填充后的标签
g.ndata['entry_code_feat'] = torch.tensor(entry_code_features, dtype=torch.float)  # c_entry_code 特征
g.ndata['kinship_count_feat'] = torch.tensor(kinship_count_features, dtype=torch.float)  # kinships 数量特征

# 输出图的基本信息
print("图的节点数：", g.num_nodes())
print("图的边数：", g.num_edges())
print("c_entry_code 特征：", g.ndata['entry_code_feat'].shape)
print("kinships 数量特征：", g.ndata['kinship_count_feat'].shape)
print("节点标签：", g.ndata['label'].shape)
# Out:
# Total nodes: 228527
# Nodes without kinships: 199471
# Proportion of nodes without kinships: 87.29%
# 图的节点数： 58726
# 图的边数： 103970
# c_entry_code 特征： torch.Size([58726, 1])
# kinships 数量特征： torch.Size([58726, 1])
# 节点标签： torch.Size([58726])

# %% [markdown]
# # 对图的一些统计

# %%
# 构图完成后重新统计入仕者比例
entry_code_feat = g.ndata['entry_code_feat'].numpy()
total_nodes_in_graph = g.num_nodes()
positive_nodes_in_graph = sum(1 for feat in entry_code_feat if feat[0] >= 0)
positive_ratio_in_graph = positive_nodes_in_graph / total_nodes_in_graph

print(f"Total nodes in graph: {total_nodes_in_graph}")
print(f"Positive nodes (入仕者数量): {positive_nodes_in_graph}")
print(f"入仕者比例: {positive_ratio_in_graph:.2%}")
# Out:
# Total nodes in graph: 3026
# Positive nodes (入仕者数量): 212
# 入仕者比例: 7.01%

# %%
# 先打印一些边信息
print(f"First 5 edges: {list(zip(edges_src, edges_dst))[:5]}")
print(f"Total number of edges: {len(edges_src)}")

# 查看节点入度信息
for node in range(g.num_nodes()):
    print(f"Node {node} in-degree: {g.in_degrees(node)}")
# Out:
# First 5 edges: [(1905, 1891), (1905, 1892), (1905, 2795), (1835, 1846), (1835, 1861)]
# Total number of edges: 3017
# Node 0 in-degree: 0
# Node 1 in-degree: 0
# Node 2 in-degree: 0
# Node 3 in-degree: 0
# Node 4 in-degree: 0
# Node 5 in-degree: 0
# Node 6 in-degree: 0
# Node 7 in-degree: 0
# Node 8 in-degree: 0
# Node 9 in-degree: 0
# Node 10 in-degree: 0
# Node 11 in-degree: 0
# Node 12 in-degree: 0
# Node 13 in-degree: 0
# Node 14 in-degree: 0
# Node 15 in-degree: 0
# Node 16 in-degree: 0
# Node 17 in-degree: 0
# Node 18 in-degree: 0
# Node 19 in-degree: 0
# Node 20 in-degree: 0
# Node 21 in-degree: 0
# Node 22 in-degree: 0
# Node 23 in-degree: 0
# Node 24 in-degree: 0
# Node 25 in-degree: 0
# Node 26 in-degree: 0
# Node 27 in-degree: 0
# Node 28 in-degree: 0
# Node 29 in-degree: 0
# Node 30 in-degree: 0
# Node 31 in-degree: 0
# Node 32 in-degree: 0
# Node 33 in-degree: 0
# Node 34 in-degree: 0
# Node 35 in-degree: 0
# Node 36 in-degree: 0
# Node 37 in-degree: 0
# Node 38 in-degree: 0
# Node 39 in-degree: 0
# Node 40 in-degree: 0
# Node 41 in-degree: 0
# Node 42 in-degree: 0
# Node 43 in-degree: 0
# Node 44 in-degree: 0
# Node 45 in-degree: 0
# Node 46 in-degree: 0
# Node 47 in-degree: 0
# Node 48 in-degree: 0
# Node 49 in-degree: 0
# Node 50 in-degree: 0
# Node 51 in-degree: 0
# Node 52 in-degree: 0
# Node 53 in-degree: 0
# Node 54 in-degree: 0
# Node 55 in-degree: 0
# Node 56 in-degree: 0
# Node 57 in-degree: 0
# Node 58 in-degree: 0
# Node 59 in-degree: 0
# Node 60 in-degree: 0
# Node 61 in-degree: 0
# Node 62 in-degree: 0
# Node 63 in-degree: 0
# Node 64 in-degree: 0
# Node 65 in-degree: 0
# Node 66 in-degree: 0
# Node 67 in-degree: 0
# Node 68 in-degree: 0
# Node 69 in-degree: 0
# Node 70 in-degree: 0
# Node 71 in-degree: 0
# Node 72 in-degree: 0
# Node 73 in-degree: 0
# Node 74 in-degree: 0
# Node 75 in-degree: 0
# Node 76 in-degree: 0
# Node 77 in-degree: 0
# Node 78 in-degree: 0
# Node 79 in-degree: 0
# Node 80 in-degree: 0
# Node 81 in-degree: 0
# Node 82 in-degree: 0
# Node 83 in-degree: 0
# Node 84 in-degree: 0
# Node 85 in-degree: 0
# Node 86 in-degree: 0
# Node 87 in-degree: 0
# Node 88 in-degree: 0
# Node 89 in-degree: 0
# Node 90 in-degree: 0
# Node 91 in-degree: 0
# Node 92 in-degree: 0
# Node 93 in-degree: 0
# Node 94 in-degree: 0
# Node 95 in-degree: 0
# Node 96 in-degree: 0
# Node 97 in-degree: 0
# Node 98 in-degree: 0
# Node 99 in-degree: 0
# Node 100 in-degree: 0
# Node 101 in-degree: 0
# Node 102 in-degree: 0
# Node 103 in-degree: 0
# Node 104 in-degree: 0
# Node 105 in-degree: 0
# Node 106 in-degree: 0
# Node 107 in-degree: 0
# Node 108 in-degree: 0
# Node 109 in-degree: 0
# Node 110 in-degree: 0
# Node 111 in-degree: 0
# Node 112 in-degree: 0
# Node 113 in-degree: 0
# Node 114 in-degree: 0
# Node 115 in-degree: 0
# Node 116 in-degree: 0
# Node 117 in-degree: 0
# Node 118 in-degree: 0
# Node 119 in-degree: 0
# Node 120 in-degree: 0
# Node 121 in-degree: 0
# Node 122 in-degree: 0
# Node 123 in-degree: 0
# Node 124 in-degree: 0
# Node 125 in-degree: 0
# Node 126 in-degree: 0
# Node 127 in-degree: 0
# Node 128 in-degree: 0
# Node 129 in-degree: 0
# Node 130 in-degree: 0
# Node 131 in-degree: 0
# Node 132 in-degree: 0
# Node 133 in-degree: 0
# Node 134 in-degree: 0
# Node 135 in-degree: 0
# Node 136 in-degree: 0
# Node 137 in-degree: 0
# Node 138 in-degree: 0
# Node 139 in-degree: 0
# Node 140 in-degree: 0
# Node 141 in-degree: 0
# Node 142 in-degree: 0
# Node 143 in-degree: 0
# Node 144 in-degree: 0
# Node 145 in-degree: 0
# Node 146 in-degree: 0
# Node 147 in-degree: 0
# Node 148 in-degree: 0
# Node 149 in-degree: 0
# Node 150 in-degree: 0
# Node 151 in-degree: 0
# Node 152 in-degree: 0
# Node 153 in-degree: 0
# Node 154 in-degree: 0
# Node 155 in-degree: 0
# Node 156 in-degree: 0
# Node 157 in-degree: 0
# Node 158 in-degree: 0
# Node 159 in-degree: 0
# Node 160 in-degree: 0
# Node 161 in-degree: 0
# Node 162 in-degree: 0
# Node 163 in-degree: 0
# Node 164 in-degree: 0
# Node 165 in-degree: 0
# Node 166 in-degree: 0
# Node 167 in-degree: 0
# Node 168 in-degree: 0
# Node 169 in-degree: 0
# Node 170 in-degree: 0
# Node 171 in-degree: 0
# Node 172 in-degree: 0
# Node 173 in-degree: 0
# Node 174 in-degree: 0
# Node 175 in-degree: 0
# Node 176 in-degree: 0
# Node 177 in-degree: 0
# Node 178 in-degree: 0
# Node 179 in-degree: 0
# Node 180 in-degree: 0
# Node 181 in-degree: 0
# Node 182 in-degree: 0
# Node 183 in-degree: 0
# Node 184 in-degree: 0
# Node 185 in-degree: 0
# Node 186 in-degree: 0
# Node 187 in-degree: 0
# Node 188 in-degree: 0
# Node 189 in-degree: 0
# Node 190 in-degree: 0
# Node 191 in-degree: 0
# Node 192 in-degree: 0
# Node 193 in-degree: 0
# Node 194 in-degree: 0
# Node 195 in-degree: 0
# Node 196 in-degree: 0
# Node 197 in-degree: 0
# Node 198 in-degree: 0
# Node 199 in-degree: 0
# Node 200 in-degree: 0
# Node 201 in-degree: 0
# Node 202 in-degree: 0
# Node 203 in-degree: 0
# Node 204 in-degree: 0
# Node 205 in-degree: 0
# Node 206 in-degree: 0
# Node 207 in-degree: 0
# Node 208 in-degree: 0
# Node 209 in-degree: 0
# Node 210 in-degree: 0
# Node 211 in-degree: 0
# Node 212 in-degree: 0
# Node 213 in-degree: 0
# Node 214 in-degree: 0
# Node 215 in-degree: 0
# Node 216 in-degree: 0
# Node 217 in-degree: 0
# Node 218 in-degree: 0
# Node 219 in-degree: 0
# Node 220 in-degree: 0
# Node 221 in-degree: 0
# Node 222 in-degree: 0
# Node 223 in-degree: 0
# Node 224 in-degree: 0
# Node 225 in-degree: 0
# Node 226 in-degree: 0
# Node 227 in-degree: 0
# Node 228 in-degree: 0
# Node 229 in-degree: 0
# Node 230 in-degree: 0
# Node 231 in-degree: 0
# Node 232 in-degree: 0
# Node 233 in-degree: 0
# Node 234 in-degree: 0
# Node 235 in-degree: 0
# Node 236 in-degree: 0
# Node 237 in-degree: 0
# Node 238 in-degree: 0
# Node 239 in-degree: 0
# Node 240 in-degree: 0
# Node 241 in-degree: 0
# Node 242 in-degree: 0
# Node 243 in-degree: 0
# Node 244 in-degree: 0
# Node 245 in-degree: 0
# Node 246 in-degree: 0
# Node 247 in-degree: 0
# Node 248 in-degree: 0
# Node 249 in-degree: 0
# Node 250 in-degree: 0
# Node 251 in-degree: 0
# Node 252 in-degree: 0
# Node 253 in-degree: 0
# Node 254 in-degree: 0
# Node 255 in-degree: 0
# Node 256 in-degree: 0
# Node 257 in-degree: 0
# Node 258 in-degree: 0
# Node 259 in-degree: 0
# Node 260 in-degree: 0
# Node 261 in-degree: 0
# Node 262 in-degree: 0
# Node 263 in-degree: 0
# Node 264 in-degree: 0
# Node 265 in-degree: 0
# Node 266 in-degree: 0
# Node 267 in-degree: 0
# Node 268 in-degree: 0
# Node 269 in-degree: 0
# Node 270 in-degree: 0
# Node 271 in-degree: 0
# Node 272 in-degree: 0
# Node 273 in-degree: 0
# Node 274 in-degree: 0
# Node 275 in-degree: 0
# Node 276 in-degree: 0
# Node 277 in-degree: 0
# Node 278 in-degree: 0
# Node 279 in-degree: 0
# Node 280 in-degree: 0
# Node 281 in-degree: 0
# Node 282 in-degree: 0
# Node 283 in-degree: 0
# Node 284 in-degree: 0
# Node 285 in-degree: 0
# Node 286 in-degree: 0
# Node 287 in-degree: 0
# Node 288 in-degree: 0
# Node 289 in-degree: 0
# Node 290 in-degree: 0
# Node 291 in-degree: 0
# Node 292 in-degree: 0
# Node 293 in-degree: 0
# Node 294 in-degree: 0
# Node 295 in-degree: 0
# Node 296 in-degree: 0
# Node 297 in-degree: 0
# Node 298 in-degree: 0
# Node 299 in-degree: 0
# Node 300 in-degree: 0
# Node 301 in-degree: 0
# Node 302 in-degree: 0
# Node 303 in-degree: 0
# Node 304 in-degree: 0
# Node 305 in-degree: 0
# Node 306 in-degree: 0
# Node 307 in-degree: 0
# Node 308 in-degree: 0
# Node 309 in-degree: 0
# Node 310 in-degree: 0
# Node 311 in-degree: 0
# Node 312 in-degree: 0
# Node 313 in-degree: 0
# Node 314 in-degree: 0
# Node 315 in-degree: 0
# Node 316 in-degree: 0
# Node 317 in-degree: 0
# Node 318 in-degree: 0
# Node 319 in-degree: 0
# Node 320 in-degree: 0
# Node 321 in-degree: 0
# Node 322 in-degree: 0
# Node 323 in-degree: 0
# Node 324 in-degree: 0
# Node 325 in-degree: 0
# Node 326 in-degree: 0
# Node 327 in-degree: 0
# Node 328 in-degree: 0
# Node 329 in-degree: 0
# Node 330 in-degree: 0
# Node 331 in-degree: 0
# Node 332 in-degree: 0
# Node 333 in-degree: 0
# Node 334 in-degree: 0
# Node 335 in-degree: 0
# Node 336 in-degree: 0
# Node 337 in-degree: 0
# Node 338 in-degree: 0
# Node 339 in-degree: 0
# Node 340 in-degree: 0
# Node 341 in-degree: 0
# Node 342 in-degree: 0
# Node 343 in-degree: 0
# Node 344 in-degree: 0
# Node 345 in-degree: 0
# Node 346 in-degree: 0
# Node 347 in-degree: 0
# Node 348 in-degree: 0
# Node 349 in-degree: 0
# Node 350 in-degree: 0
# Node 351 in-degree: 0
# Node 352 in-degree: 0
# Node 353 in-degree: 0
# Node 354 in-degree: 0
# Node 355 in-degree: 0
# Node 356 in-degree: 0
# Node 357 in-degree: 0
# Node 358 in-degree: 0
# Node 359 in-degree: 0
# Node 360 in-degree: 0
# Node 361 in-degree: 0
# Node 362 in-degree: 0
# Node 363 in-degree: 0
# Node 364 in-degree: 0
# Node 365 in-degree: 0
# Node 366 in-degree: 0
# Node 367 in-degree: 0
# Node 368 in-degree: 0
# Node 369 in-degree: 0
# Node 370 in-degree: 0
# Node 371 in-degree: 0
# Node 372 in-degree: 0
# Node 373 in-degree: 0
# Node 374 in-degree: 0
# Node 375 in-degree: 0
# Node 376 in-degree: 0
# Node 377 in-degree: 0
# Node 378 in-degree: 0
# Node 379 in-degree: 0
# Node 380 in-degree: 0
# Node 381 in-degree: 0
# Node 382 in-degree: 0
# Node 383 in-degree: 0
# Node 384 in-degree: 0
# Node 385 in-degree: 0
# Node 386 in-degree: 0
# Node 387 in-degree: 0
# Node 388 in-degree: 0
# Node 389 in-degree: 0
# Node 390 in-degree: 0
# Node 391 in-degree: 0
# Node 392 in-degree: 0
# Node 393 in-degree: 0
# Node 394 in-degree: 0
# Node 395 in-degree: 0
# Node 396 in-degree: 0
# Node 397 in-degree: 0
# Node 398 in-degree: 0
# Node 399 in-degree: 0
# Node 400 in-degree: 0
# Node 401 in-degree: 0
# Node 402 in-degree: 0
# Node 403 in-degree: 0
# Node 404 in-degree: 0
# Node 405 in-degree: 0
# Node 406 in-degree: 0
# Node 407 in-degree: 0
# Node 408 in-degree: 0
# Node 409 in-degree: 0
# Node 410 in-degree: 0
# Node 411 in-degree: 0
# Node 412 in-degree: 0
# Node 413 in-degree: 0
# Node 414 in-degree: 0
# Node 415 in-degree: 0
# Node 416 in-degree: 0
# Node 417 in-degree: 0
# Node 418 in-degree: 0
# Node 419 in-degree: 0
# Node 420 in-degree: 0
# Node 421 in-degree: 0
# Node 422 in-degree: 0
# Node 423 in-degree: 0
# Node 424 in-degree: 0
# Node 425 in-degree: 0
# Node 426 in-degree: 0
# Node 427 in-degree: 0
# Node 428 in-degree: 0
# Node 429 in-degree: 0
# Node 430 in-degree: 0
# Node 431 in-degree: 0
# Node 432 in-degree: 0
# Node 433 in-degree: 0
# Node 434 in-degree: 0
# Node 435 in-degree: 0
# Node 436 in-degree: 0
# Node 437 in-degree: 0
# Node 438 in-degree: 0
# Node 439 in-degree: 0
# Node 440 in-degree: 0
# Node 441 in-degree: 0
# Node 442 in-degree: 0
# Node 443 in-degree: 0
# Node 444 in-degree: 0
# Node 445 in-degree: 0
# Node 446 in-degree: 0
# Node 447 in-degree: 0
# Node 448 in-degree: 0
# Node 449 in-degree: 0
# Node 450 in-degree: 0
# Node 451 in-degree: 0
# Node 452 in-degree: 0
# Node 453 in-degree: 0
# Node 454 in-degree: 0
# Node 455 in-degree: 0
# Node 456 in-degree: 0
# Node 457 in-degree: 0
# Node 458 in-degree: 0
# Node 459 in-degree: 0
# Node 460 in-degree: 0
# Node 461 in-degree: 0
# Node 462 in-degree: 0
# Node 463 in-degree: 0
# Node 464 in-degree: 0
# Node 465 in-degree: 0
# Node 466 in-degree: 0
# Node 467 in-degree: 0
# Node 468 in-degree: 0
# Node 469 in-degree: 0
# Node 470 in-degree: 0
# Node 471 in-degree: 0
# Node 472 in-degree: 0
# Node 473 in-degree: 0
# Node 474 in-degree: 0
# Node 475 in-degree: 0
# Node 476 in-degree: 0
# Node 477 in-degree: 0
# Node 478 in-degree: 0
# Node 479 in-degree: 0
# Node 480 in-degree: 0
# Node 481 in-degree: 0
# Node 482 in-degree: 0
# Node 483 in-degree: 0
# Node 484 in-degree: 0
# Node 485 in-degree: 0
# Node 486 in-degree: 0
# Node 487 in-degree: 0
# Node 488 in-degree: 0
# Node 489 in-degree: 0
# Node 490 in-degree: 0
# Node 491 in-degree: 0
# Node 492 in-degree: 0
# Node 493 in-degree: 0
# Node 494 in-degree: 0
# Node 495 in-degree: 0
# Node 496 in-degree: 0
# Node 497 in-degree: 0
# Node 498 in-degree: 0
# Node 499 in-degree: 0
# Node 500 in-degree: 0
# Node 501 in-degree: 0
# Node 502 in-degree: 0
# Node 503 in-degree: 0
# Node 504 in-degree: 0
# Node 505 in-degree: 0
# Node 506 in-degree: 0
# Node 507 in-degree: 0
# Node 508 in-degree: 0
# Node 509 in-degree: 0
# Node 510 in-degree: 0
# Node 511 in-degree: 0
# Node 512 in-degree: 0
# Node 513 in-degree: 0
# Node 514 in-degree: 0
# Node 515 in-degree: 0
# Node 516 in-degree: 0
# Node 517 in-degree: 0
# Node 518 in-degree: 0
# Node 519 in-degree: 0
# Node 520 in-degree: 0
# Node 521 in-degree: 0
# Node 522 in-degree: 0
# Node 523 in-degree: 0
# Node 524 in-degree: 0
# Node 525 in-degree: 0
# Node 526 in-degree: 0
# Node 527 in-degree: 0
# Node 528 in-degree: 0
# Node 529 in-degree: 0
# Node 530 in-degree: 0
# Node 531 in-degree: 0
# Node 532 in-degree: 0
# Node 533 in-degree: 0
# Node 534 in-degree: 0
# Node 535 in-degree: 0
# Node 536 in-degree: 0
# Node 537 in-degree: 0
# Node 538 in-degree: 0
# Node 539 in-degree: 0
# Node 540 in-degree: 0
# Node 541 in-degree: 0
# Node 542 in-degree: 0
# Node 543 in-degree: 0
# Node 544 in-degree: 0
# Node 545 in-degree: 0
# Node 546 in-degree: 0
# Node 547 in-degree: 0
# Node 548 in-degree: 0
# Node 549 in-degree: 0
# Node 550 in-degree: 0
# Node 551 in-degree: 0
# Node 552 in-degree: 0
# Node 553 in-degree: 0
# Node 554 in-degree: 0
# Node 555 in-degree: 0
# Node 556 in-degree: 0
# Node 557 in-degree: 0
# Node 558 in-degree: 0
# Node 559 in-degree: 0
# Node 560 in-degree: 0
# Node 561 in-degree: 0
# Node 562 in-degree: 0
# Node 563 in-degree: 0
# Node 564 in-degree: 0
# Node 565 in-degree: 0
# Node 566 in-degree: 0
# Node 567 in-degree: 0
# Node 568 in-degree: 0
# Node 569 in-degree: 0
# Node 570 in-degree: 0
# Node 571 in-degree: 0
# Node 572 in-degree: 0
# Node 573 in-degree: 0
# Node 574 in-degree: 0
# Node 575 in-degree: 0
# Node 576 in-degree: 0
# Node 577 in-degree: 0
# Node 578 in-degree: 0
# Node 579 in-degree: 0
# Node 580 in-degree: 0
# Node 581 in-degree: 0
# Node 582 in-degree: 0
# Node 583 in-degree: 0
# Node 584 in-degree: 0
# Node 585 in-degree: 0
# Node 586 in-degree: 0
# Node 587 in-degree: 0
# Node 588 in-degree: 0
# Node 589 in-degree: 0
# Node 590 in-degree: 0
# Node 591 in-degree: 0
# Node 592 in-degree: 0
# Node 593 in-degree: 0
# Node 594 in-degree: 0
# Node 595 in-degree: 0
# Node 596 in-degree: 0
# Node 597 in-degree: 0
# Node 598 in-degree: 0
# Node 599 in-degree: 0
# Node 600 in-degree: 0
# Node 601 in-degree: 0
# Node 602 in-degree: 0
# Node 603 in-degree: 0
# Node 604 in-degree: 0
# Node 605 in-degree: 0
# Node 606 in-degree: 0
# Node 607 in-degree: 0
# Node 608 in-degree: 0
# Node 609 in-degree: 0
# Node 610 in-degree: 0
# Node 611 in-degree: 0
# Node 612 in-degree: 0
# Node 613 in-degree: 0
# Node 614 in-degree: 0
# Node 615 in-degree: 0
# Node 616 in-degree: 0
# Node 617 in-degree: 0
# Node 618 in-degree: 0
# Node 619 in-degree: 0
# Node 620 in-degree: 0
# Node 621 in-degree: 0
# Node 622 in-degree: 0
# Node 623 in-degree: 0
# Node 624 in-degree: 0
# Node 625 in-degree: 0
# Node 626 in-degree: 0
# Node 627 in-degree: 0
# Node 628 in-degree: 0
# Node 629 in-degree: 0
# Node 630 in-degree: 0
# Node 631 in-degree: 0
# Node 632 in-degree: 0
# Node 633 in-degree: 0
# Node 634 in-degree: 0
# Node 635 in-degree: 0
# Node 636 in-degree: 0
# Node 637 in-degree: 0
# Node 638 in-degree: 0
# Node 639 in-degree: 0
# Node 640 in-degree: 0
# Node 641 in-degree: 0
# Node 642 in-degree: 0
# Node 643 in-degree: 0
# Node 644 in-degree: 0
# Node 645 in-degree: 0
# Node 646 in-degree: 0
# Node 647 in-degree: 0
# Node 648 in-degree: 0
# Node 649 in-degree: 0
# Node 650 in-degree: 0
# Node 651 in-degree: 0
# Node 652 in-degree: 0
# Node 653 in-degree: 0
# Node 654 in-degree: 0
# Node 655 in-degree: 0
# Node 656 in-degree: 0
# Node 657 in-degree: 0
# Node 658 in-degree: 0
# Node 659 in-degree: 0
# Node 660 in-degree: 0
# Node 661 in-degree: 0
# Node 662 in-degree: 0
# Node 663 in-degree: 0
# Node 664 in-degree: 0
# Node 665 in-degree: 0
# Node 666 in-degree: 0
# Node 667 in-degree: 0
# Node 668 in-degree: 0
# Node 669 in-degree: 0
# Node 670 in-degree: 0
# Node 671 in-degree: 0
# Node 672 in-degree: 0
# Node 673 in-degree: 0
# Node 674 in-degree: 0
# Node 675 in-degree: 0
# Node 676 in-degree: 0
# Node 677 in-degree: 0
# Node 678 in-degree: 0
# Node 679 in-degree: 0
# Node 680 in-degree: 0
# Node 681 in-degree: 0
# Node 682 in-degree: 0
# Node 683 in-degree: 0
# Node 684 in-degree: 0
# Node 685 in-degree: 0
# Node 686 in-degree: 0
# Node 687 in-degree: 0
# Node 688 in-degree: 0
# Node 689 in-degree: 0
# Node 690 in-degree: 0
# Node 691 in-degree: 0
# Node 692 in-degree: 0
# Node 693 in-degree: 0
# Node 694 in-degree: 0
# Node 695 in-degree: 0
# Node 696 in-degree: 0
# Node 697 in-degree: 0
# Node 698 in-degree: 0
# Node 699 in-degree: 0
# Node 700 in-degree: 0
# Node 701 in-degree: 0
# Node 702 in-degree: 0
# Node 703 in-degree: 0
# Node 704 in-degree: 0
# Node 705 in-degree: 0
# Node 706 in-degree: 0
# Node 707 in-degree: 0
# Node 708 in-degree: 0
# Node 709 in-degree: 0
# Node 710 in-degree: 0
# Node 711 in-degree: 0
# Node 712 in-degree: 0
# Node 713 in-degree: 0
# Node 714 in-degree: 0
# Node 715 in-degree: 0
# Node 716 in-degree: 0
# Node 717 in-degree: 0
# Node 718 in-degree: 0
# Node 719 in-degree: 0
# Node 720 in-degree: 0
# Node 721 in-degree: 0
# Node 722 in-degree: 0
# Node 723 in-degree: 0
# Node 724 in-degree: 0
# Node 725 in-degree: 0
# Node 726 in-degree: 0
# Node 727 in-degree: 0
# Node 728 in-degree: 0
# Node 729 in-degree: 0
# Node 730 in-degree: 0
# Node 731 in-degree: 0
# Node 732 in-degree: 0
# Node 733 in-degree: 0
# Node 734 in-degree: 0
# Node 735 in-degree: 0
# Node 736 in-degree: 0
# Node 737 in-degree: 0
# Node 738 in-degree: 0
# Node 739 in-degree: 0
# Node 740 in-degree: 0
# Node 741 in-degree: 0
# Node 742 in-degree: 0
# Node 743 in-degree: 0
# Node 744 in-degree: 0
# Node 745 in-degree: 0
# Node 746 in-degree: 0
# Node 747 in-degree: 0
# Node 748 in-degree: 0
# Node 749 in-degree: 0
# Node 750 in-degree: 0
# Node 751 in-degree: 0
# Node 752 in-degree: 0
# Node 753 in-degree: 0
# Node 754 in-degree: 0
# Node 755 in-degree: 0
# Node 756 in-degree: 0
# Node 757 in-degree: 0
# Node 758 in-degree: 0
# Node 759 in-degree: 0
# Node 760 in-degree: 0
# Node 761 in-degree: 0
# Node 762 in-degree: 0
# Node 763 in-degree: 0
# Node 764 in-degree: 0
# Node 765 in-degree: 0
# Node 766 in-degree: 0
# Node 767 in-degree: 0
# Node 768 in-degree: 0
# Node 769 in-degree: 0
# Node 770 in-degree: 0
# Node 771 in-degree: 0
# Node 772 in-degree: 0
# Node 773 in-degree: 0
# Node 774 in-degree: 0
# Node 775 in-degree: 0
# Node 776 in-degree: 0
# Node 777 in-degree: 0
# Node 778 in-degree: 0
# Node 779 in-degree: 0
# Node 780 in-degree: 0
# Node 781 in-degree: 0
# Node 782 in-degree: 0
# Node 783 in-degree: 0
# Node 784 in-degree: 0
# Node 785 in-degree: 0
# Node 786 in-degree: 0
# Node 787 in-degree: 0
# Node 788 in-degree: 0
# Node 789 in-degree: 0
# Node 790 in-degree: 0
# Node 791 in-degree: 0
# Node 792 in-degree: 0
# Node 793 in-degree: 0
# Node 794 in-degree: 0
# Node 795 in-degree: 0
# Node 796 in-degree: 0
# Node 797 in-degree: 0
# Node 798 in-degree: 0
# Node 799 in-degree: 0
# Node 800 in-degree: 0
# Node 801 in-degree: 0
# Node 802 in-degree: 0
# Node 803 in-degree: 0
# Node 804 in-degree: 0
# Node 805 in-degree: 0
# Node 806 in-degree: 0
# Node 807 in-degree: 0
# Node 808 in-degree: 0
# Node 809 in-degree: 0
# Node 810 in-degree: 0
# Node 811 in-degree: 0
# Node 812 in-degree: 0
# Node 813 in-degree: 0
# Node 814 in-degree: 0
# Node 815 in-degree: 0
# Node 816 in-degree: 0
# Node 817 in-degree: 0
# Node 818 in-degree: 0
# Node 819 in-degree: 0
# Node 820 in-degree: 0
# Node 821 in-degree: 0
# Node 822 in-degree: 0
# Node 823 in-degree: 0
# Node 824 in-degree: 0
# Node 825 in-degree: 0
# Node 826 in-degree: 0
# Node 827 in-degree: 0
# Node 828 in-degree: 0
# Node 829 in-degree: 0
# Node 830 in-degree: 0
# Node 831 in-degree: 0
# Node 832 in-degree: 0
# Node 833 in-degree: 0
# Node 834 in-degree: 0
# Node 835 in-degree: 0
# Node 836 in-degree: 0
# Node 837 in-degree: 0
# Node 838 in-degree: 0
# Node 839 in-degree: 0
# Node 840 in-degree: 0
# Node 841 in-degree: 0
# Node 842 in-degree: 0
# Node 843 in-degree: 0
# Node 844 in-degree: 0
# Node 845 in-degree: 0
# Node 846 in-degree: 0
# Node 847 in-degree: 0
# Node 848 in-degree: 0
# Node 849 in-degree: 0
# Node 850 in-degree: 0
# Node 851 in-degree: 0
# Node 852 in-degree: 0
# Node 853 in-degree: 0
# Node 854 in-degree: 0
# Node 855 in-degree: 0
# Node 856 in-degree: 0
# Node 857 in-degree: 0
# Node 858 in-degree: 0
# Node 859 in-degree: 0
# Node 860 in-degree: 0
# Node 861 in-degree: 0
# Node 862 in-degree: 0
# Node 863 in-degree: 0
# Node 864 in-degree: 0
# Node 865 in-degree: 0
# Node 866 in-degree: 0
# Node 867 in-degree: 0
# Node 868 in-degree: 0
# Node 869 in-degree: 0
# Node 870 in-degree: 0
# Node 871 in-degree: 0
# Node 872 in-degree: 0
# Node 873 in-degree: 0
# Node 874 in-degree: 0
# Node 875 in-degree: 0
# Node 876 in-degree: 0
# Node 877 in-degree: 0
# Node 878 in-degree: 0
# Node 879 in-degree: 0
# Node 880 in-degree: 0
# Node 881 in-degree: 0
# Node 882 in-degree: 0
# Node 883 in-degree: 0
# Node 884 in-degree: 0
# Node 885 in-degree: 0
# Node 886 in-degree: 0
# Node 887 in-degree: 0
# Node 888 in-degree: 0
# Node 889 in-degree: 0
# Node 890 in-degree: 0
# Node 891 in-degree: 0
# Node 892 in-degree: 0
# Node 893 in-degree: 0
# Node 894 in-degree: 0
# Node 895 in-degree: 0
# Node 896 in-degree: 0
# Node 897 in-degree: 0
# Node 898 in-degree: 0
# Node 899 in-degree: 0
# Node 900 in-degree: 0
# Node 901 in-degree: 0
# Node 902 in-degree: 0
# Node 903 in-degree: 0
# Node 904 in-degree: 0
# Node 905 in-degree: 0
# Node 906 in-degree: 0
# Node 907 in-degree: 0
# Node 908 in-degree: 0
# Node 909 in-degree: 0
# Node 910 in-degree: 0
# Node 911 in-degree: 0
# Node 912 in-degree: 0
# Node 913 in-degree: 0
# Node 914 in-degree: 0
# Node 915 in-degree: 0
# Node 916 in-degree: 0
# Node 917 in-degree: 0
# Node 918 in-degree: 0
# Node 919 in-degree: 0
# Node 920 in-degree: 0
# Node 921 in-degree: 0
# Node 922 in-degree: 0
# Node 923 in-degree: 0
# Node 924 in-degree: 0
# Node 925 in-degree: 0
# Node 926 in-degree: 0
# Node 927 in-degree: 0
# Node 928 in-degree: 0
# Node 929 in-degree: 0
# Node 930 in-degree: 0
# Node 931 in-degree: 0
# Node 932 in-degree: 0
# Node 933 in-degree: 0
# Node 934 in-degree: 0
# Node 935 in-degree: 0
# Node 936 in-degree: 0
# Node 937 in-degree: 0
# Node 938 in-degree: 0
# Node 939 in-degree: 0
# Node 940 in-degree: 0
# Node 941 in-degree: 0
# Node 942 in-degree: 0
# Node 943 in-degree: 0
# Node 944 in-degree: 0
# Node 945 in-degree: 0
# Node 946 in-degree: 0
# Node 947 in-degree: 0
# Node 948 in-degree: 0
# Node 949 in-degree: 0
# Node 950 in-degree: 0
# Node 951 in-degree: 0
# Node 952 in-degree: 0
# Node 953 in-degree: 0
# Node 954 in-degree: 0
# Node 955 in-degree: 0
# Node 956 in-degree: 0
# Node 957 in-degree: 0
# Node 958 in-degree: 0
# Node 959 in-degree: 0
# Node 960 in-degree: 0
# Node 961 in-degree: 0
# Node 962 in-degree: 0
# Node 963 in-degree: 0
# Node 964 in-degree: 0
# Node 965 in-degree: 0
# Node 966 in-degree: 0
# Node 967 in-degree: 0
# Node 968 in-degree: 0
# Node 969 in-degree: 0
# Node 970 in-degree: 0
# Node 971 in-degree: 0
# Node 972 in-degree: 0
# Node 973 in-degree: 0
# Node 974 in-degree: 0
# Node 975 in-degree: 0
# Node 976 in-degree: 0
# Node 977 in-degree: 0
# Node 978 in-degree: 0
# Node 979 in-degree: 0
# Node 980 in-degree: 0
# Node 981 in-degree: 0
# Node 982 in-degree: 0
# Node 983 in-degree: 0
# Node 984 in-degree: 0
# Node 985 in-degree: 0
# Node 986 in-degree: 0
# Node 987 in-degree: 0
# Node 988 in-degree: 0
# Node 989 in-degree: 0
# Node 990 in-degree: 0
# Node 991 in-degree: 0
# Node 992 in-degree: 0
# Node 993 in-degree: 0
# Node 994 in-degree: 0
# Node 995 in-degree: 0
# Node 996 in-degree: 0
# Node 997 in-degree: 0
# Node 998 in-degree: 0
# Node 999 in-degree: 0
# Node 1000 in-degree: 0
# Node 1001 in-degree: 0
# Node 1002 in-degree: 0
# Node 1003 in-degree: 0
# Node 1004 in-degree: 0
# Node 1005 in-degree: 0
# Node 1006 in-degree: 0
# Node 1007 in-degree: 0
# Node 1008 in-degree: 0
# Node 1009 in-degree: 0
# Node 1010 in-degree: 0
# Node 1011 in-degree: 0
# Node 1012 in-degree: 0
# Node 1013 in-degree: 0
# Node 1014 in-degree: 0
# Node 1015 in-degree: 0
# Node 1016 in-degree: 0
# Node 1017 in-degree: 0
# Node 1018 in-degree: 0
# Node 1019 in-degree: 0
# Node 1020 in-degree: 0
# Node 1021 in-degree: 0
# Node 1022 in-degree: 0
# Node 1023 in-degree: 0
# Node 1024 in-degree: 0
# Node 1025 in-degree: 0
# Node 1026 in-degree: 0
# Node 1027 in-degree: 0
# Node 1028 in-degree: 0
# Node 1029 in-degree: 0
# Node 1030 in-degree: 0
# Node 1031 in-degree: 0
# Node 1032 in-degree: 0
# Node 1033 in-degree: 0
# Node 1034 in-degree: 0
# Node 1035 in-degree: 0
# Node 1036 in-degree: 0
# Node 1037 in-degree: 0
# Node 1038 in-degree: 1
# Node 1039 in-degree: 1
# Node 1040 in-degree: 1
# Node 1041 in-degree: 1
# Node 1042 in-degree: 1
# Node 1043 in-degree: 1
# Node 1044 in-degree: 1
# Node 1045 in-degree: 1
# Node 1046 in-degree: 1
# Node 1047 in-degree: 1
# Node 1048 in-degree: 1
# Node 1049 in-degree: 1
# Node 1050 in-degree: 1
# Node 1051 in-degree: 1
# Node 1052 in-degree: 1
# Node 1053 in-degree: 1
# Node 1054 in-degree: 1
# Node 1055 in-degree: 1
# Node 1056 in-degree: 1
# Node 1057 in-degree: 2
# Node 1058 in-degree: 1
# Node 1059 in-degree: 1
# Node 1060 in-degree: 1
# Node 1061 in-degree: 1
# Node 1062 in-degree: 1
# Node 1063 in-degree: 1
# Node 1064 in-degree: 1
# Node 1065 in-degree: 1
# Node 1066 in-degree: 1
# Node 1067 in-degree: 1
# Node 1068 in-degree: 1
# Node 1069 in-degree: 1
# Node 1070 in-degree: 2
# Node 1071 in-degree: 2
# Node 1072 in-degree: 2
# Node 1073 in-degree: 1
# Node 1074 in-degree: 2
# Node 1075 in-degree: 1
# Node 1076 in-degree: 1
# Node 1077 in-degree: 1
# Node 1078 in-degree: 1
# Node 1079 in-degree: 2
# Node 1080 in-degree: 1
# Node 1081 in-degree: 1
# Node 1082 in-degree: 1
# Node 1083 in-degree: 1
# Node 1084 in-degree: 1
# Node 1085 in-degree: 2
# Node 1086 in-degree: 1
# Node 1087 in-degree: 1
# Node 1088 in-degree: 1
# Node 1089 in-degree: 1
# Node 1090 in-degree: 1
# Node 1091 in-degree: 1
# Node 1092 in-degree: 1
# Node 1093 in-degree: 1
# Node 1094 in-degree: 1
# Node 1095 in-degree: 1
# Node 1096 in-degree: 1
# Node 1097 in-degree: 1
# Node 1098 in-degree: 1
# Node 1099 in-degree: 1
# Node 1100 in-degree: 1
# Node 1101 in-degree: 1
# Node 1102 in-degree: 1
# Node 1103 in-degree: 1
# Node 1104 in-degree: 1
# Node 1105 in-degree: 1
# Node 1106 in-degree: 1
# Node 1107 in-degree: 1
# Node 1108 in-degree: 1
# Node 1109 in-degree: 2
# Node 1110 in-degree: 1
# Node 1111 in-degree: 1
# Node 1112 in-degree: 1
# Node 1113 in-degree: 1
# Node 1114 in-degree: 1
# Node 1115 in-degree: 1
# Node 1116 in-degree: 1
# Node 1117 in-degree: 1
# Node 1118 in-degree: 1
# Node 1119 in-degree: 1
# Node 1120 in-degree: 1
# Node 1121 in-degree: 1
# Node 1122 in-degree: 1
# Node 1123 in-degree: 1
# Node 1124 in-degree: 1
# Node 1125 in-degree: 1
# Node 1126 in-degree: 1
# Node 1127 in-degree: 1
# Node 1128 in-degree: 5
# Node 1129 in-degree: 1
# Node 1130 in-degree: 1
# Node 1131 in-degree: 1
# Node 1132 in-degree: 1
# Node 1133 in-degree: 1
# Node 1134 in-degree: 1
# Node 1135 in-degree: 1
# Node 1136 in-degree: 1
# Node 1137 in-degree: 1
# Node 1138 in-degree: 1
# Node 1139 in-degree: 1
# Node 1140 in-degree: 1
# Node 1141 in-degree: 1
# Node 1142 in-degree: 1
# Node 1143 in-degree: 1
# Node 1144 in-degree: 2
# Node 1145 in-degree: 2
# Node 1146 in-degree: 1
# Node 1147 in-degree: 1
# Node 1148 in-degree: 1
# Node 1149 in-degree: 1
# Node 1150 in-degree: 1
# Node 1151 in-degree: 1
# Node 1152 in-degree: 1
# Node 1153 in-degree: 1
# Node 1154 in-degree: 1
# Node 1155 in-degree: 1
# Node 1156 in-degree: 1
# Node 1157 in-degree: 1
# Node 1158 in-degree: 2
# Node 1159 in-degree: 5
# Node 1160 in-degree: 1
# Node 1161 in-degree: 1
# Node 1162 in-degree: 1
# Node 1163 in-degree: 1
# Node 1164 in-degree: 1
# Node 1165 in-degree: 1
# Node 1166 in-degree: 1
# Node 1167 in-degree: 1
# Node 1168 in-degree: 1
# Node 1169 in-degree: 2
# Node 1170 in-degree: 1
# Node 1171 in-degree: 2
# Node 1172 in-degree: 2
# Node 1173 in-degree: 1
# Node 1174 in-degree: 1
# Node 1175 in-degree: 2
# Node 1176 in-degree: 1
# Node 1177 in-degree: 1
# Node 1178 in-degree: 1
# Node 1179 in-degree: 1
# Node 1180 in-degree: 1
# Node 1181 in-degree: 2
# Node 1182 in-degree: 1
# Node 1183 in-degree: 1
# Node 1184 in-degree: 1
# Node 1185 in-degree: 1
# Node 1186 in-degree: 1
# Node 1187 in-degree: 1
# Node 1188 in-degree: 1
# Node 1189 in-degree: 1
# Node 1190 in-degree: 1
# Node 1191 in-degree: 1
# Node 1192 in-degree: 1
# Node 1193 in-degree: 1
# Node 1194 in-degree: 1
# Node 1195 in-degree: 1
# Node 1196 in-degree: 1
# Node 1197 in-degree: 1
# Node 1198 in-degree: 1
# Node 1199 in-degree: 1
# Node 1200 in-degree: 1
# Node 1201 in-degree: 1
# Node 1202 in-degree: 1
# Node 1203 in-degree: 1
# Node 1204 in-degree: 1
# Node 1205 in-degree: 1
# Node 1206 in-degree: 1
# Node 1207 in-degree: 1
# Node 1208 in-degree: 1
# Node 1209 in-degree: 1
# Node 1210 in-degree: 1
# Node 1211 in-degree: 1
# Node 1212 in-degree: 2
# Node 1213 in-degree: 2
# Node 1214 in-degree: 2
# Node 1215 in-degree: 2
# Node 1216 in-degree: 5
# Node 1217 in-degree: 3
# Node 1218 in-degree: 2
# Node 1219 in-degree: 1
# Node 1220 in-degree: 1
# Node 1221 in-degree: 1
# Node 1222 in-degree: 1
# Node 1223 in-degree: 1
# Node 1224 in-degree: 1
# Node 1225 in-degree: 1
# Node 1226 in-degree: 1
# Node 1227 in-degree: 1
# Node 1228 in-degree: 2
# Node 1229 in-degree: 1
# Node 1230 in-degree: 1
# Node 1231 in-degree: 1
# Node 1232 in-degree: 1
# Node 1233 in-degree: 1
# Node 1234 in-degree: 2
# Node 1235 in-degree: 1
# Node 1236 in-degree: 1
# Node 1237 in-degree: 1
# Node 1238 in-degree: 2
# Node 1239 in-degree: 1
# Node 1240 in-degree: 1
# Node 1241 in-degree: 1
# Node 1242 in-degree: 1
# Node 1243 in-degree: 1
# Node 1244 in-degree: 1
# Node 1245 in-degree: 1
# Node 1246 in-degree: 1
# Node 1247 in-degree: 1
# Node 1248 in-degree: 1
# Node 1249 in-degree: 1
# Node 1250 in-degree: 1
# Node 1251 in-degree: 1
# Node 1252 in-degree: 1
# Node 1253 in-degree: 1
# Node 1254 in-degree: 1
# Node 1255 in-degree: 1
# Node 1256 in-degree: 1
# Node 1257 in-degree: 1
# Node 1258 in-degree: 1
# Node 1259 in-degree: 1
# Node 1260 in-degree: 1
# Node 1261 in-degree: 1
# Node 1262 in-degree: 3
# Node 1263 in-degree: 1
# Node 1264 in-degree: 1
# Node 1265 in-degree: 1
# Node 1266 in-degree: 1
# Node 1267 in-degree: 1
# Node 1268 in-degree: 1
# Node 1269 in-degree: 1
# Node 1270 in-degree: 1
# Node 1271 in-degree: 1
# Node 1272 in-degree: 1
# Node 1273 in-degree: 1
# Node 1274 in-degree: 1
# Node 1275 in-degree: 1
# Node 1276 in-degree: 1
# Node 1277 in-degree: 1
# Node 1278 in-degree: 1
# Node 1279 in-degree: 1
# Node 1280 in-degree: 1
# Node 1281 in-degree: 1
# Node 1282 in-degree: 1
# Node 1283 in-degree: 1
# Node 1284 in-degree: 1
# Node 1285 in-degree: 1
# Node 1286 in-degree: 1
# Node 1287 in-degree: 1
# Node 1288 in-degree: 1
# Node 1289 in-degree: 1
# Node 1290 in-degree: 1
# Node 1291 in-degree: 1
# Node 1292 in-degree: 1
# Node 1293 in-degree: 1
# Node 1294 in-degree: 1
# Node 1295 in-degree: 1
# Node 1296 in-degree: 1
# Node 1297 in-degree: 1
# Node 1298 in-degree: 1
# Node 1299 in-degree: 1
# Node 1300 in-degree: 1
# Node 1301 in-degree: 1
# Node 1302 in-degree: 1
# Node 1303 in-degree: 1
# Node 1304 in-degree: 1
# Node 1305 in-degree: 1
# Node 1306 in-degree: 1
# Node 1307 in-degree: 1
# Node 1308 in-degree: 1
# Node 1309 in-degree: 1
# Node 1310 in-degree: 2
# Node 1311 in-degree: 1
# Node 1312 in-degree: 2
# Node 1313 in-degree: 2
# Node 1314 in-degree: 1
# Node 1315 in-degree: 1
# Node 1316 in-degree: 2
# Node 1317 in-degree: 1
# Node 1318 in-degree: 1
# Node 1319 in-degree: 1
# Node 1320 in-degree: 1
# Node 1321 in-degree: 2
# Node 1322 in-degree: 3
# Node 1323 in-degree: 1
# Node 1324 in-degree: 1
# Node 1325 in-degree: 1
# Node 1326 in-degree: 1
# Node 1327 in-degree: 1
# Node 1328 in-degree: 1
# Node 1329 in-degree: 1
# Node 1330 in-degree: 1
# Node 1331 in-degree: 1
# Node 1332 in-degree: 1
# Node 1333 in-degree: 1
# Node 1334 in-degree: 1
# Node 1335 in-degree: 1
# Node 1336 in-degree: 1
# Node 1337 in-degree: 1
# Node 1338 in-degree: 1
# Node 1339 in-degree: 1
# Node 1340 in-degree: 1
# Node 1341 in-degree: 1
# Node 1342 in-degree: 3
# Node 1343 in-degree: 1
# Node 1344 in-degree: 1
# Node 1345 in-degree: 1
# Node 1346 in-degree: 3
# Node 1347 in-degree: 1
# Node 1348 in-degree: 1
# Node 1349 in-degree: 1
# Node 1350 in-degree: 1
# Node 1351 in-degree: 1
# Node 1352 in-degree: 1
# Node 1353 in-degree: 1
# Node 1354 in-degree: 1
# Node 1355 in-degree: 1
# Node 1356 in-degree: 1
# Node 1357 in-degree: 1
# Node 1358 in-degree: 2
# Node 1359 in-degree: 2
# Node 1360 in-degree: 2
# Node 1361 in-degree: 1
# Node 1362 in-degree: 1
# Node 1363 in-degree: 1
# Node 1364 in-degree: 1
# Node 1365 in-degree: 1
# Node 1366 in-degree: 1
# Node 1367 in-degree: 1
# Node 1368 in-degree: 1
# Node 1369 in-degree: 1
# Node 1370 in-degree: 1
# Node 1371 in-degree: 1
# Node 1372 in-degree: 1
# Node 1373 in-degree: 1
# Node 1374 in-degree: 1
# Node 1375 in-degree: 1
# Node 1376 in-degree: 1
# Node 1377 in-degree: 1
# Node 1378 in-degree: 1
# Node 1379 in-degree: 1
# Node 1380 in-degree: 2
# Node 1381 in-degree: 1
# Node 1382 in-degree: 1
# Node 1383 in-degree: 1
# Node 1384 in-degree: 3
# Node 1385 in-degree: 1
# Node 1386 in-degree: 1
# Node 1387 in-degree: 1
# Node 1388 in-degree: 1
# Node 1389 in-degree: 1
# Node 1390 in-degree: 1
# Node 1391 in-degree: 2
# Node 1392 in-degree: 1
# Node 1393 in-degree: 1
# Node 1394 in-degree: 1
# Node 1395 in-degree: 1
# Node 1396 in-degree: 1
# Node 1397 in-degree: 1
# Node 1398 in-degree: 1
# Node 1399 in-degree: 1
# Node 1400 in-degree: 1
# Node 1401 in-degree: 1
# Node 1402 in-degree: 1
# Node 1403 in-degree: 1
# Node 1404 in-degree: 1
# Node 1405 in-degree: 1
# Node 1406 in-degree: 1
# Node 1407 in-degree: 1
# Node 1408 in-degree: 1
# Node 1409 in-degree: 1
# Node 1410 in-degree: 1
# Node 1411 in-degree: 1
# Node 1412 in-degree: 1
# Node 1413 in-degree: 1
# Node 1414 in-degree: 1
# Node 1415 in-degree: 1
# Node 1416 in-degree: 1
# Node 1417 in-degree: 1
# Node 1418 in-degree: 1
# Node 1419 in-degree: 1
# Node 1420 in-degree: 1
# Node 1421 in-degree: 1
# Node 1422 in-degree: 1
# Node 1423 in-degree: 1
# Node 1424 in-degree: 1
# Node 1425 in-degree: 1
# Node 1426 in-degree: 1
# Node 1427 in-degree: 1
# Node 1428 in-degree: 1
# Node 1429 in-degree: 1
# Node 1430 in-degree: 1
# Node 1431 in-degree: 1
# Node 1432 in-degree: 1
# Node 1433 in-degree: 1
# Node 1434 in-degree: 1
# Node 1435 in-degree: 1
# Node 1436 in-degree: 1
# Node 1437 in-degree: 1
# Node 1438 in-degree: 3
# Node 1439 in-degree: 1
# Node 1440 in-degree: 1
# Node 1441 in-degree: 1
# Node 1442 in-degree: 1
# Node 1443 in-degree: 1
# Node 1444 in-degree: 1
# Node 1445 in-degree: 1
# Node 1446 in-degree: 1
# Node 1447 in-degree: 2
# Node 1448 in-degree: 1
# Node 1449 in-degree: 1
# Node 1450 in-degree: 2
# Node 1451 in-degree: 1
# Node 1452 in-degree: 1
# Node 1453 in-degree: 1
# Node 1454 in-degree: 3
# Node 1455 in-degree: 1
# Node 1456 in-degree: 1
# Node 1457 in-degree: 1
# Node 1458 in-degree: 1
# Node 1459 in-degree: 1
# Node 1460 in-degree: 2
# Node 1461 in-degree: 1
# Node 1462 in-degree: 1
# Node 1463 in-degree: 2
# Node 1464 in-degree: 2
# Node 1465 in-degree: 2
# Node 1466 in-degree: 1
# Node 1467 in-degree: 1
# Node 1468 in-degree: 1
# Node 1469 in-degree: 1
# Node 1470 in-degree: 1
# Node 1471 in-degree: 1
# Node 1472 in-degree: 1
# Node 1473 in-degree: 1
# Node 1474 in-degree: 1
# Node 1475 in-degree: 1
# Node 1476 in-degree: 1
# Node 1477 in-degree: 1
# Node 1478 in-degree: 1
# Node 1479 in-degree: 1
# Node 1480 in-degree: 1
# Node 1481 in-degree: 1
# Node 1482 in-degree: 1
# Node 1483 in-degree: 2
# Node 1484 in-degree: 1
# Node 1485 in-degree: 1
# Node 1486 in-degree: 1
# Node 1487 in-degree: 1
# Node 1488 in-degree: 3
# Node 1489 in-degree: 1
# Node 1490 in-degree: 1
# Node 1491 in-degree: 2
# Node 1492 in-degree: 1
# Node 1493 in-degree: 1
# Node 1494 in-degree: 1
# Node 1495 in-degree: 1
# Node 1496 in-degree: 1
# Node 1497 in-degree: 1
# Node 1498 in-degree: 1
# Node 1499 in-degree: 1
# Node 1500 in-degree: 1
# Node 1501 in-degree: 1
# Node 1502 in-degree: 1
# Node 1503 in-degree: 1
# Node 1504 in-degree: 1
# Node 1505 in-degree: 1
# Node 1506 in-degree: 1
# Node 1507 in-degree: 1
# Node 1508 in-degree: 1
# Node 1509 in-degree: 1
# Node 1510 in-degree: 1
# Node 1511 in-degree: 1
# Node 1512 in-degree: 1
# Node 1513 in-degree: 1
# Node 1514 in-degree: 2
# Node 1515 in-degree: 1
# Node 1516 in-degree: 1
# Node 1517 in-degree: 1
# Node 1518 in-degree: 1
# Node 1519 in-degree: 2
# Node 1520 in-degree: 1
# Node 1521 in-degree: 1
# Node 1522 in-degree: 1
# Node 1523 in-degree: 1
# Node 1524 in-degree: 4
# Node 1525 in-degree: 4
# Node 1526 in-degree: 3
# Node 1527 in-degree: 2
# Node 1528 in-degree: 3
# Node 1529 in-degree: 1
# Node 1530 in-degree: 1
# Node 1531 in-degree: 1
# Node 1532 in-degree: 3
# Node 1533 in-degree: 2
# Node 1534 in-degree: 1
# Node 1535 in-degree: 2
# Node 1536 in-degree: 1
# Node 1537 in-degree: 1
# Node 1538 in-degree: 1
# Node 1539 in-degree: 1
# Node 1540 in-degree: 1
# Node 1541 in-degree: 1
# Node 1542 in-degree: 1
# Node 1543 in-degree: 1
# Node 1544 in-degree: 1
# Node 1545 in-degree: 1
# Node 1546 in-degree: 1
# Node 1547 in-degree: 1
# Node 1548 in-degree: 2
# Node 1549 in-degree: 1
# Node 1550 in-degree: 1
# Node 1551 in-degree: 1
# Node 1552 in-degree: 1
# Node 1553 in-degree: 1
# Node 1554 in-degree: 2
# Node 1555 in-degree: 1
# Node 1556 in-degree: 2
# Node 1557 in-degree: 1
# Node 1558 in-degree: 2
# Node 1559 in-degree: 1
# Node 1560 in-degree: 1
# Node 1561 in-degree: 1
# Node 1562 in-degree: 1
# Node 1563 in-degree: 1
# Node 1564 in-degree: 1
# Node 1565 in-degree: 1
# Node 1566 in-degree: 1
# Node 1567 in-degree: 1
# Node 1568 in-degree: 1
# Node 1569 in-degree: 1
# Node 1570 in-degree: 1
# Node 1571 in-degree: 1
# Node 1572 in-degree: 1
# Node 1573 in-degree: 1
# Node 1574 in-degree: 1
# Node 1575 in-degree: 2
# Node 1576 in-degree: 1
# Node 1577 in-degree: 2
# Node 1578 in-degree: 2
# Node 1579 in-degree: 2
# Node 1580 in-degree: 2
# Node 1581 in-degree: 1
# Node 1582 in-degree: 1
# Node 1583 in-degree: 1
# Node 1584 in-degree: 1
# Node 1585 in-degree: 1
# Node 1586 in-degree: 1
# Node 1587 in-degree: 2
# Node 1588 in-degree: 1
# Node 1589 in-degree: 1
# Node 1590 in-degree: 1
# Node 1591 in-degree: 2
# Node 1592 in-degree: 1
# Node 1593 in-degree: 1
# Node 1594 in-degree: 1
# Node 1595 in-degree: 1
# Node 1596 in-degree: 1
# Node 1597 in-degree: 1
# Node 1598 in-degree: 3
# Node 1599 in-degree: 1
# Node 1600 in-degree: 2
# Node 1601 in-degree: 1
# Node 1602 in-degree: 1
# Node 1603 in-degree: 1
# Node 1604 in-degree: 1
# Node 1605 in-degree: 1
# Node 1606 in-degree: 1
# Node 1607 in-degree: 1
# Node 1608 in-degree: 1
# Node 1609 in-degree: 1
# Node 1610 in-degree: 1
# Node 1611 in-degree: 11
# Node 1612 in-degree: 2
# Node 1613 in-degree: 1
# Node 1614 in-degree: 4
# Node 1615 in-degree: 1
# Node 1616 in-degree: 3
# Node 1617 in-degree: 2
# Node 1618 in-degree: 7
# Node 1619 in-degree: 1
# Node 1620 in-degree: 1
# Node 1621 in-degree: 1
# Node 1622 in-degree: 4
# Node 1623 in-degree: 2
# Node 1624 in-degree: 2
# Node 1625 in-degree: 3
# Node 1626 in-degree: 3
# Node 1627 in-degree: 1
# Node 1628 in-degree: 3
# Node 1629 in-degree: 4
# Node 1630 in-degree: 1
# Node 1631 in-degree: 1
# Node 1632 in-degree: 2
# Node 1633 in-degree: 2
# Node 1634 in-degree: 4
# Node 1635 in-degree: 2
# Node 1636 in-degree: 4
# Node 1637 in-degree: 2
# Node 1638 in-degree: 3
# Node 1639 in-degree: 5
# Node 1640 in-degree: 3
# Node 1641 in-degree: 3
# Node 1642 in-degree: 3
# Node 1643 in-degree: 4
# Node 1644 in-degree: 4
# Node 1645 in-degree: 1
# Node 1646 in-degree: 1
# Node 1647 in-degree: 4
# Node 1648 in-degree: 3
# Node 1649 in-degree: 4
# Node 1650 in-degree: 4
# Node 1651 in-degree: 2
# Node 1652 in-degree: 1
# Node 1653 in-degree: 2
# Node 1654 in-degree: 1
# Node 1655 in-degree: 2
# Node 1656 in-degree: 4
# Node 1657 in-degree: 3
# Node 1658 in-degree: 1
# Node 1659 in-degree: 1
# Node 1660 in-degree: 1
# Node 1661 in-degree: 1
# Node 1662 in-degree: 4
# Node 1663 in-degree: 5
# Node 1664 in-degree: 4
# Node 1665 in-degree: 5
# Node 1666 in-degree: 2
# Node 1667 in-degree: 1
# Node 1668 in-degree: 1
# Node 1669 in-degree: 3
# Node 1670 in-degree: 1
# Node 1671 in-degree: 1
# Node 1672 in-degree: 1
# Node 1673 in-degree: 3
# Node 1674 in-degree: 1
# Node 1675 in-degree: 1
# Node 1676 in-degree: 1
# Node 1677 in-degree: 3
# Node 1678 in-degree: 2
# Node 1679 in-degree: 4
# Node 1680 in-degree: 2
# Node 1681 in-degree: 2
# Node 1682 in-degree: 1
# Node 1683 in-degree: 1
# Node 1684 in-degree: 3
# Node 1685 in-degree: 1
# Node 1686 in-degree: 1
# Node 1687 in-degree: 2
# Node 1688 in-degree: 1
# Node 1689 in-degree: 1
# Node 1690 in-degree: 1
# Node 1691 in-degree: 1
# Node 1692 in-degree: 2
# Node 1693 in-degree: 6
# Node 1694 in-degree: 3
# Node 1695 in-degree: 1
# Node 1696 in-degree: 3
# Node 1697 in-degree: 4
# Node 1698 in-degree: 4
# Node 1699 in-degree: 2
# Node 1700 in-degree: 1
# Node 1701 in-degree: 3
# Node 1702 in-degree: 1
# Node 1703 in-degree: 2
# Node 1704 in-degree: 1
# Node 1705 in-degree: 1
# Node 1706 in-degree: 1
# Node 1707 in-degree: 1
# Node 1708 in-degree: 3
# Node 1709 in-degree: 1
# Node 1710 in-degree: 3
# Node 1711 in-degree: 2
# Node 1712 in-degree: 2
# Node 1713 in-degree: 2
# Node 1714 in-degree: 5
# Node 1715 in-degree: 2
# Node 1716 in-degree: 1
# Node 1717 in-degree: 2
# Node 1718 in-degree: 1
# Node 1719 in-degree: 1
# Node 1720 in-degree: 5
# Node 1721 in-degree: 2
# Node 1722 in-degree: 2
# Node 1723 in-degree: 1
# Node 1724 in-degree: 14
# Node 1725 in-degree: 6
# Node 1726 in-degree: 1
# Node 1727 in-degree: 5
# Node 1728 in-degree: 1
# Node 1729 in-degree: 1
# Node 1730 in-degree: 4
# Node 1731 in-degree: 2
# Node 1732 in-degree: 1
# Node 1733 in-degree: 1
# Node 1734 in-degree: 1
# Node 1735 in-degree: 1
# Node 1736 in-degree: 1
# Node 1737 in-degree: 1
# Node 1738 in-degree: 9
# Node 1739 in-degree: 2
# Node 1740 in-degree: 6
# Node 1741 in-degree: 2
# Node 1742 in-degree: 2
# Node 1743 in-degree: 1
# Node 1744 in-degree: 2
# Node 1745 in-degree: 1
# Node 1746 in-degree: 5
# Node 1747 in-degree: 2
# Node 1748 in-degree: 1
# Node 1749 in-degree: 2
# Node 1750 in-degree: 2
# Node 1751 in-degree: 1
# Node 1752 in-degree: 3
# Node 1753 in-degree: 2
# Node 1754 in-degree: 3
# Node 1755 in-degree: 2
# Node 1756 in-degree: 2
# Node 1757 in-degree: 1
# Node 1758 in-degree: 4
# Node 1759 in-degree: 4
# Node 1760 in-degree: 3
# Node 1761 in-degree: 3
# Node 1762 in-degree: 3
# Node 1763 in-degree: 2
# Node 1764 in-degree: 1
# Node 1765 in-degree: 2
# Node 1766 in-degree: 1
# Node 1767 in-degree: 2
# Node 1768 in-degree: 2
# Node 1769 in-degree: 1
# Node 1770 in-degree: 1
# Node 1771 in-degree: 4
# Node 1772 in-degree: 2
# Node 1773 in-degree: 2
# Node 1774 in-degree: 1
# Node 1775 in-degree: 1
# Node 1776 in-degree: 1
# Node 1777 in-degree: 3
# Node 1778 in-degree: 1
# Node 1779 in-degree: 3
# Node 1780 in-degree: 3
# Node 1781 in-degree: 2
# Node 1782 in-degree: 2
# Node 1783 in-degree: 1
# Node 1784 in-degree: 2
# Node 1785 in-degree: 1
# Node 1786 in-degree: 4
# Node 1787 in-degree: 1
# Node 1788 in-degree: 2
# Node 1789 in-degree: 2
# Node 1790 in-degree: 1
# Node 1791 in-degree: 1
# Node 1792 in-degree: 1
# Node 1793 in-degree: 3
# Node 1794 in-degree: 1
# Node 1795 in-degree: 2
# Node 1796 in-degree: 2
# Node 1797 in-degree: 6
# Node 1798 in-degree: 2
# Node 1799 in-degree: 1
# Node 1800 in-degree: 1
# Node 1801 in-degree: 2
# Node 1802 in-degree: 3
# Node 1803 in-degree: 3
# Node 1804 in-degree: 2
# Node 1805 in-degree: 4
# Node 1806 in-degree: 1
# Node 1807 in-degree: 4
# Node 1808 in-degree: 2
# Node 1809 in-degree: 2
# Node 1810 in-degree: 2
# Node 1811 in-degree: 1
# Node 1812 in-degree: 1
# Node 1813 in-degree: 2
# Node 1814 in-degree: 3
# Node 1815 in-degree: 1
# Node 1816 in-degree: 3
# Node 1817 in-degree: 1
# Node 1818 in-degree: 1
# Node 1819 in-degree: 1
# Node 1820 in-degree: 2
# Node 1821 in-degree: 1
# Node 1822 in-degree: 3
# Node 1823 in-degree: 4
# Node 1824 in-degree: 3
# Node 1825 in-degree: 1
# Node 1826 in-degree: 3
# Node 1827 in-degree: 2
# Node 1828 in-degree: 1
# Node 1829 in-degree: 2
# Node 1830 in-degree: 1
# Node 1831 in-degree: 3
# Node 1832 in-degree: 1
# Node 1833 in-degree: 1
# Node 1834 in-degree: 1
# Node 1835 in-degree: 1
# Node 1836 in-degree: 3
# Node 1837 in-degree: 2
# Node 1838 in-degree: 1
# Node 1839 in-degree: 3
# Node 1840 in-degree: 1
# Node 1841 in-degree: 2
# Node 1842 in-degree: 1
# Node 1843 in-degree: 1
# Node 1844 in-degree: 1
# Node 1845 in-degree: 1
# Node 1846 in-degree: 1
# Node 1847 in-degree: 2
# Node 1848 in-degree: 1
# Node 1849 in-degree: 1
# Node 1850 in-degree: 1
# Node 1851 in-degree: 1
# Node 1852 in-degree: 1
# Node 1853 in-degree: 2
# Node 1854 in-degree: 1
# Node 1855 in-degree: 1
# Node 1856 in-degree: 1
# Node 1857 in-degree: 1
# Node 1858 in-degree: 1
# Node 1859 in-degree: 1
# Node 1860 in-degree: 1
# Node 1861 in-degree: 1
# Node 1862 in-degree: 1
# Node 1863 in-degree: 1
# Node 1864 in-degree: 1
# Node 1865 in-degree: 2
# Node 1866 in-degree: 1
# Node 1867 in-degree: 3
# Node 1868 in-degree: 1
# Node 1869 in-degree: 2
# Node 1870 in-degree: 2
# Node 1871 in-degree: 3
# Node 1872 in-degree: 1
# Node 1873 in-degree: 1
# Node 1874 in-degree: 1
# Node 1875 in-degree: 1
# Node 1876 in-degree: 1
# Node 1877 in-degree: 2
# Node 1878 in-degree: 1
# Node 1879 in-degree: 2
# Node 1880 in-degree: 1
# Node 1881 in-degree: 3
# Node 1882 in-degree: 2
# Node 1883 in-degree: 1
# Node 1884 in-degree: 1
# Node 1885 in-degree: 1
# Node 1886 in-degree: 1
# Node 1887 in-degree: 1
# Node 1888 in-degree: 6
# Node 1889 in-degree: 2
# Node 1890 in-degree: 1
# Node 1891 in-degree: 3
# Node 1892 in-degree: 7
# Node 1893 in-degree: 1
# Node 1894 in-degree: 2
# Node 1895 in-degree: 5
# Node 1896 in-degree: 1
# Node 1897 in-degree: 1
# Node 1898 in-degree: 3
# Node 1899 in-degree: 1
# Node 1900 in-degree: 1
# Node 1901 in-degree: 2
# Node 1902 in-degree: 1
# Node 1903 in-degree: 1
# Node 1904 in-degree: 1
# Node 1905 in-degree: 3
# Node 1906 in-degree: 1
# Node 1907 in-degree: 1
# Node 1908 in-degree: 1
# Node 1909 in-degree: 1
# Node 1910 in-degree: 1
# Node 1911 in-degree: 4
# Node 1912 in-degree: 4
# Node 1913 in-degree: 3
# Node 1914 in-degree: 1
# Node 1915 in-degree: 1
# Node 1916 in-degree: 1
# Node 1917 in-degree: 2
# Node 1918 in-degree: 1
# Node 1919 in-degree: 1
# Node 1920 in-degree: 2
# Node 1921 in-degree: 1
# Node 1922 in-degree: 1
# Node 1923 in-degree: 1
# Node 1924 in-degree: 1
# Node 1925 in-degree: 1
# Node 1926 in-degree: 1
# Node 1927 in-degree: 1
# Node 1928 in-degree: 7
# Node 1929 in-degree: 1
# Node 1930 in-degree: 2
# Node 1931 in-degree: 1
# Node 1932 in-degree: 1
# Node 1933 in-degree: 1
# Node 1934 in-degree: 2
# Node 1935 in-degree: 1
# Node 1936 in-degree: 1
# Node 1937 in-degree: 4
# Node 1938 in-degree: 1
# Node 1939 in-degree: 4
# Node 1940 in-degree: 1
# Node 1941 in-degree: 1
# Node 1942 in-degree: 2
# Node 1943 in-degree: 1
# Node 1944 in-degree: 1
# Node 1945 in-degree: 1
# Node 1946 in-degree: 3
# Node 1947 in-degree: 2
# Node 1948 in-degree: 1
# Node 1949 in-degree: 2
# Node 1950 in-degree: 1
# Node 1951 in-degree: 1
# Node 1952 in-degree: 1
# Node 1953 in-degree: 1
# Node 1954 in-degree: 6
# Node 1955 in-degree: 1
# Node 1956 in-degree: 3
# Node 1957 in-degree: 1
# Node 1958 in-degree: 3
# Node 1959 in-degree: 3
# Node 1960 in-degree: 5
# Node 1961 in-degree: 7
# Node 1962 in-degree: 8
# Node 1963 in-degree: 1
# Node 1964 in-degree: 2
# Node 1965 in-degree: 5
# Node 1966 in-degree: 3
# Node 1967 in-degree: 3
# Node 1968 in-degree: 1
# Node 1969 in-degree: 3
# Node 1970 in-degree: 2
# Node 1971 in-degree: 1
# Node 1972 in-degree: 4
# Node 1973 in-degree: 2
# Node 1974 in-degree: 7
# Node 1975 in-degree: 1
# Node 1976 in-degree: 3
# Node 1977 in-degree: 1
# Node 1978 in-degree: 2
# Node 1979 in-degree: 3
# Node 1980 in-degree: 2
# Node 1981 in-degree: 3
# Node 1982 in-degree: 3
# Node 1983 in-degree: 1
# Node 1984 in-degree: 3
# Node 1985 in-degree: 2
# Node 1986 in-degree: 1
# Node 1987 in-degree: 2
# Node 1988 in-degree: 2
# Node 1989 in-degree: 2
# Node 1990 in-degree: 2
# Node 1991 in-degree: 1
# Node 1992 in-degree: 1
# Node 1993 in-degree: 4
# Node 1994 in-degree: 1
# Node 1995 in-degree: 1
# Node 1996 in-degree: 1
# Node 1997 in-degree: 1
# Node 1998 in-degree: 1
# Node 1999 in-degree: 1
# Node 2000 in-degree: 3
# Node 2001 in-degree: 2
# Node 2002 in-degree: 3
# Node 2003 in-degree: 3
# Node 2004 in-degree: 2
# Node 2005 in-degree: 1
# Node 2006 in-degree: 1
# Node 2007 in-degree: 2
# Node 2008 in-degree: 1
# Node 2009 in-degree: 1
# Node 2010 in-degree: 2
# Node 2011 in-degree: 1
# Node 2012 in-degree: 2
# Node 2013 in-degree: 1
# Node 2014 in-degree: 1
# Node 2015 in-degree: 2
# Node 2016 in-degree: 1
# Node 2017 in-degree: 1
# Node 2018 in-degree: 1
# Node 2019 in-degree: 1
# Node 2020 in-degree: 2
# Node 2021 in-degree: 2
# Node 2022 in-degree: 2
# Node 2023 in-degree: 3
# Node 2024 in-degree: 1
# Node 2025 in-degree: 1
# Node 2026 in-degree: 1
# Node 2027 in-degree: 2
# Node 2028 in-degree: 2
# Node 2029 in-degree: 2
# Node 2030 in-degree: 1
# Node 2031 in-degree: 1
# Node 2032 in-degree: 1
# Node 2033 in-degree: 1
# Node 2034 in-degree: 3
# Node 2035 in-degree: 1
# Node 2036 in-degree: 1
# Node 2037 in-degree: 1
# Node 2038 in-degree: 1
# Node 2039 in-degree: 1
# Node 2040 in-degree: 1
# Node 2041 in-degree: 1
# Node 2042 in-degree: 1
# Node 2043 in-degree: 2
# Node 2044 in-degree: 1
# Node 2045 in-degree: 2
# Node 2046 in-degree: 1
# Node 2047 in-degree: 2
# Node 2048 in-degree: 1
# Node 2049 in-degree: 1
# Node 2050 in-degree: 1
# Node 2051 in-degree: 1
# Node 2052 in-degree: 2
# Node 2053 in-degree: 1
# Node 2054 in-degree: 1
# Node 2055 in-degree: 1
# Node 2056 in-degree: 1
# Node 2057 in-degree: 3
# Node 2058 in-degree: 3
# Node 2059 in-degree: 3
# Node 2060 in-degree: 3
# Node 2061 in-degree: 3
# Node 2062 in-degree: 1
# Node 2063 in-degree: 2
# Node 2064 in-degree: 2
# Node 2065 in-degree: 2
# Node 2066 in-degree: 2
# Node 2067 in-degree: 2
# Node 2068 in-degree: 1
# Node 2069 in-degree: 1
# Node 2070 in-degree: 1
# Node 2071 in-degree: 1
# Node 2072 in-degree: 2
# Node 2073 in-degree: 6
# Node 2074 in-degree: 3
# Node 2075 in-degree: 2
# Node 2076 in-degree: 2
# Node 2077 in-degree: 1
# Node 2078 in-degree: 2
# Node 2079 in-degree: 2
# Node 2080 in-degree: 1
# Node 2081 in-degree: 1
# Node 2082 in-degree: 1
# Node 2083 in-degree: 2
# Node 2084 in-degree: 1
# Node 2085 in-degree: 1
# Node 2086 in-degree: 1
# Node 2087 in-degree: 1
# Node 2088 in-degree: 1
# Node 2089 in-degree: 3
# Node 2090 in-degree: 2
# Node 2091 in-degree: 1
# Node 2092 in-degree: 2
# Node 2093 in-degree: 1
# Node 2094 in-degree: 1
# Node 2095 in-degree: 1
# Node 2096 in-degree: 1
# Node 2097 in-degree: 1
# Node 2098 in-degree: 1
# Node 2099 in-degree: 2
# Node 2100 in-degree: 3
# Node 2101 in-degree: 2
# Node 2102 in-degree: 1
# Node 2103 in-degree: 2
# Node 2104 in-degree: 2
# Node 2105 in-degree: 2
# Node 2106 in-degree: 1
# Node 2107 in-degree: 1
# Node 2108 in-degree: 2
# Node 2109 in-degree: 2
# Node 2110 in-degree: 1
# Node 2111 in-degree: 1
# Node 2112 in-degree: 1
# Node 2113 in-degree: 2
# Node 2114 in-degree: 3
# Node 2115 in-degree: 1
# Node 2116 in-degree: 1
# Node 2117 in-degree: 8
# Node 2118 in-degree: 1
# Node 2119 in-degree: 2
# Node 2120 in-degree: 1
# Node 2121 in-degree: 3
# Node 2122 in-degree: 3
# Node 2123 in-degree: 2
# Node 2124 in-degree: 4
# Node 2125 in-degree: 1
# Node 2126 in-degree: 2
# Node 2127 in-degree: 1
# Node 2128 in-degree: 1
# Node 2129 in-degree: 1
# ...
# Node 2331 in-degree: 2
# Node 2332 in-degree: 1
# Node 2333 in-degree: 1
# Node 2334 in-degree: 1
# Node 2335 in-degree: 1
# Node 2336 in-degree: 5
# Node 2337 in-degree: 4
# Node 2338 in-degree: 2
# Node 2339 in-degree: 5
# Node 2340 in-degree: 2
# Node 2341 in-degree: 3
# Node 2342 in-degree: 6
# Node 2343 in-degree: 2
# Node 2344 in-degree: 1
# Node 2345 in-degree: 1
# Node 2346 in-degree: 1
# Node 2347 in-degree: 2
# Node 2348 in-degree: 1
# Node 2349 in-degree: 2
# Node 2350 in-degree: 1
# Node 2351 in-degree: 1
# Node 2352 in-degree: 1
# Node 2353 in-degree: 1
# Node 2354 in-degree: 1
# Node 2355 in-degree: 1
# Node 2356 in-degree: 1
# Node 2357 in-degree: 1
# Node 2358 in-degree: 3
# Node 2359 in-degree: 1
# Node 2360 in-degree: 2
# Node 2361 in-degree: 2
# Node 2362 in-degree: 2
# Node 2363 in-degree: 5
# Node 2364 in-degree: 2
# Node 2365 in-degree: 2
# Node 2366 in-degree: 1
# Node 2367 in-degree: 1
# Node 2368 in-degree: 3
# Node 2369 in-degree: 3
# Node 2370 in-degree: 1
# Node 2371 in-degree: 1
# Node 2372 in-degree: 1
# Node 2373 in-degree: 1
# Node 2374 in-degree: 1
# Node 2375 in-degree: 1
# Node 2376 in-degree: 1
# Node 2377 in-degree: 1
# Node 2378 in-degree: 1
# Node 2379 in-degree: 2
# Node 2380 in-degree: 2
# Node 2381 in-degree: 1
# Node 2382 in-degree: 1
# Node 2383 in-degree: 2
# Node 2384 in-degree: 1
# Node 2385 in-degree: 1
# Node 2386 in-degree: 1
# Node 2387 in-degree: 1
# Node 2388 in-degree: 1
# Node 2389 in-degree: 1
# Node 2390 in-degree: 3
# Node 2391 in-degree: 2
# Node 2392 in-degree: 1
# Node 2393 in-degree: 1
# Node 2394 in-degree: 1
# Node 2395 in-degree: 1
# Node 2396 in-degree: 1
# Node 2397 in-degree: 1
# Node 2398 in-degree: 1
# Node 2399 in-degree: 1
# Node 2400 in-degree: 1
# Node 2401 in-degree: 1
# Node 2402 in-degree: 1
# Node 2403 in-degree: 1
# Node 2404 in-degree: 2
# Node 2405 in-degree: 1
# Node 2406 in-degree: 3
# Node 2407 in-degree: 2
# Node 2408 in-degree: 1
# Node 2409 in-degree: 2
# Node 2410 in-degree: 1
# Node 2411 in-degree: 1
# Node 2412 in-degree: 1
# Node 2413 in-degree: 1
# Node 2414 in-degree: 3
# Node 2415 in-degree: 1
# Node 2416 in-degree: 1
# Node 2417 in-degree: 2
# Node 2418 in-degree: 2
# Node 2419 in-degree: 1
# Node 2420 in-degree: 1
# Node 2421 in-degree: 1
# Node 2422 in-degree: 1
# Node 2423 in-degree: 1
# Node 2424 in-degree: 2
# Node 2425 in-degree: 1
# Node 2426 in-degree: 1
# Node 2427 in-degree: 1
# Node 2428 in-degree: 2
# Node 2429 in-degree: 1
# Node 2430 in-degree: 1
# Node 2431 in-degree: 1
# Node 2432 in-degree: 1
# Node 2433 in-degree: 1
# Node 2434 in-degree: 2
# Node 2435 in-degree: 1
# Node 2436 in-degree: 1
# Node 2437 in-degree: 1
# Node 2438 in-degree: 1
# Node 2439 in-degree: 2
# Node 2440 in-degree: 1
# Node 2441 in-degree: 6
# Node 2442 in-degree: 2
# Node 2443 in-degree: 1
# Node 2444 in-degree: 8
# Node 2445 in-degree: 1
# Node 2446 in-degree: 9
# Node 2447 in-degree: 1
# Node 2448 in-degree: 1
# Node 2449 in-degree: 6
# Node 2450 in-degree: 1
# Node 2451 in-degree: 2
# Node 2452 in-degree: 1
# Node 2453 in-degree: 5
# Node 2454 in-degree: 1
# Node 2455 in-degree: 1
# Node 2456 in-degree: 2
# Node 2457 in-degree: 6
# Node 2458 in-degree: 2
# Node 2459 in-degree: 6
# Node 2460 in-degree: 2
# Node 2461 in-degree: 1
# Node 2462 in-degree: 2
# Node 2463 in-degree: 1
# Node 2464 in-degree: 1
# Node 2465 in-degree: 1
# Node 2466 in-degree: 1
# Node 2467 in-degree: 1
# Node 2468 in-degree: 1
# Node 2469 in-degree: 1
# Node 2470 in-degree: 2
# Node 2471 in-degree: 1
# Node 2472 in-degree: 1
# Node 2473 in-degree: 1
# Node 2474 in-degree: 1
# Node 2475 in-degree: 1
# Node 2476 in-degree: 1
# Node 2477 in-degree: 1
# Node 2478 in-degree: 1
# Node 2479 in-degree: 1
# Node 2480 in-degree: 1
# Node 2481 in-degree: 1
# Node 2482 in-degree: 1
# Node 2483 in-degree: 1
# Node 2484 in-degree: 1
# Node 2485 in-degree: 2
# Node 2486 in-degree: 2
# Node 2487 in-degree: 1
# Node 2488 in-degree: 1
# Node 2489 in-degree: 1
# Node 2490 in-degree: 1
# Node 2491 in-degree: 1
# Node 2492 in-degree: 1
# Node 2493 in-degree: 1
# Node 2494 in-degree: 1
# Node 2495 in-degree: 1
# Node 2496 in-degree: 1
# Node 2497 in-degree: 1
# Node 2498 in-degree: 1
# Node 2499 in-degree: 1
# Node 2500 in-degree: 2
# Node 2501 in-degree: 1
# Node 2502 in-degree: 1
# Node 2503 in-degree: 1
# Node 2504 in-degree: 2
# Node 2505 in-degree: 1
# Node 2506 in-degree: 1
# Node 2507 in-degree: 1
# Node 2508 in-degree: 2
# Node 2509 in-degree: 1
# Node 2510 in-degree: 1
# Node 2511 in-degree: 1
# Node 2512 in-degree: 2
# Node 2513 in-degree: 1
# Node 2514 in-degree: 2
# Node 2515 in-degree: 2
# Node 2516 in-degree: 1
# Node 2517 in-degree: 1
# Node 2518 in-degree: 1
# Node 2519 in-degree: 1
# Node 2520 in-degree: 2
# Node 2521 in-degree: 1
# Node 2522 in-degree: 1
# Node 2523 in-degree: 1
# Node 2524 in-degree: 1
# Node 2525 in-degree: 1
# Node 2526 in-degree: 1
# Node 2527 in-degree: 2
# Node 2528 in-degree: 1
# Node 2529 in-degree: 1
# Node 2530 in-degree: 1
# Node 2531 in-degree: 1
# Node 2532 in-degree: 1
# Node 2533 in-degree: 1
# Node 2534 in-degree: 1
# Node 2535 in-degree: 2
# Node 2536 in-degree: 2
# Node 2537 in-degree: 2
# Node 2538 in-degree: 1
# Node 2539 in-degree: 1
# Node 2540 in-degree: 1
# Node 2541 in-degree: 1
# Node 2542 in-degree: 1
# Node 2543 in-degree: 1
# Node 2544 in-degree: 1
# Node 2545 in-degree: 1
# Node 2546 in-degree: 1
# Node 2547 in-degree: 1
# Node 2548 in-degree: 1
# Node 2549 in-degree: 1
# Node 2550 in-degree: 1
# Node 2551 in-degree: 1
# Node 2552 in-degree: 1
# Node 2553 in-degree: 1
# Node 2554 in-degree: 1
# Node 2555 in-degree: 1
# Node 2556 in-degree: 1
# Node 2557 in-degree: 1
# Node 2558 in-degree: 1
# Node 2559 in-degree: 1
# Node 2560 in-degree: 4
# Node 2561 in-degree: 1
# Node 2562 in-degree: 4
# Node 2563 in-degree: 1
# Node 2564 in-degree: 1
# Node 2565 in-degree: 1
# Node 2566 in-degree: 1
# Node 2567 in-degree: 1
# Node 2568 in-degree: 1
# Node 2569 in-degree: 1
# Node 2570 in-degree: 1
# Node 2571 in-degree: 1
# Node 2572 in-degree: 4
# Node 2573 in-degree: 1
# Node 2574 in-degree: 3
# Node 2575 in-degree: 1
# Node 2576 in-degree: 1
# Node 2577 in-degree: 1
# Node 2578 in-degree: 1
# Node 2579 in-degree: 2
# Node 2580 in-degree: 1
# Node 2581 in-degree: 1
# Node 2582 in-degree: 1
# Node 2583 in-degree: 1
# Node 2584 in-degree: 1
# Node 2585 in-degree: 1
# Node 2586 in-degree: 1
# Node 2587 in-degree: 1
# Node 2588 in-degree: 1
# Node 2589 in-degree: 1
# Node 2590 in-degree: 1
# Node 2591 in-degree: 1
# Node 2592 in-degree: 1
# Node 2593 in-degree: 1
# Node 2594 in-degree: 1
# Node 2595 in-degree: 1
# Node 2596 in-degree: 1
# Node 2597 in-degree: 1
# Node 2598 in-degree: 1
# Node 2599 in-degree: 1
# Node 2600 in-degree: 1
# Node 2601 in-degree: 1
# Node 2602 in-degree: 1
# Node 2603 in-degree: 1
# Node 2604 in-degree: 1
# Node 2605 in-degree: 1
# Node 2606 in-degree: 1
# Node 2607 in-degree: 1
# Node 2608 in-degree: 1
# Node 2609 in-degree: 1
# Node 2610 in-degree: 1
# Node 2611 in-degree: 1
# Node 2612 in-degree: 1
# Node 2613 in-degree: 1
# Node 2614 in-degree: 1
# Node 2615 in-degree: 1
# Node 2616 in-degree: 1
# Node 2617 in-degree: 1
# Node 2618 in-degree: 1
# Node 2619 in-degree: 1
# Node 2620 in-degree: 1
# Node 2621 in-degree: 1
# Node 2622 in-degree: 1
# Node 2623 in-degree: 1
# Node 2624 in-degree: 1
# Node 2625 in-degree: 1
# Node 2626 in-degree: 1
# Node 2627 in-degree: 1
# Node 2628 in-degree: 1
# Node 2629 in-degree: 1
# Node 2630 in-degree: 1
# Node 2631 in-degree: 1
# Node 2632 in-degree: 1
# Node 2633 in-degree: 1
# Node 2634 in-degree: 7
# Node 2635 in-degree: 1
# Node 2636 in-degree: 7
# Node 2637 in-degree: 1
# Node 2638 in-degree: 2
# Node 2639 in-degree: 3
# Node 2640 in-degree: 1
# Node 2641 in-degree: 1
# Node 2642 in-degree: 1
# Node 2643 in-degree: 2
# Node 2644 in-degree: 7
# Node 2645 in-degree: 1
# Node 2646 in-degree: 7
# Node 2647 in-degree: 7
# Node 2648 in-degree: 1
# Node 2649 in-degree: 1
# Node 2650 in-degree: 7
# Node 2651 in-degree: 1
# Node 2652 in-degree: 7
# Node 2653 in-degree: 1
# Node 2654 in-degree: 1
# Node 2655 in-degree: 1
# Node 2656 in-degree: 7
# Node 2657 in-degree: 1
# Node 2658 in-degree: 1
# Node 2659 in-degree: 1
# Node 2660 in-degree: 1
# Node 2661 in-degree: 1
# Node 2662 in-degree: 1
# Node 2663 in-degree: 2
# Node 2664 in-degree: 1
# Node 2665 in-degree: 1
# Node 2666 in-degree: 3
# Node 2667 in-degree: 2
# Node 2668 in-degree: 3
# Node 2669 in-degree: 2
# Node 2670 in-degree: 1
# Node 2671 in-degree: 1
# Node 2672 in-degree: 1
# Node 2673 in-degree: 3
# Node 2674 in-degree: 1
# Node 2675 in-degree: 1
# Node 2676 in-degree: 2
# Node 2677 in-degree: 4
# Node 2678 in-degree: 1
# Node 2679 in-degree: 1
# Node 2680 in-degree: 2
# Node 2681 in-degree: 1
# Node 2682 in-degree: 1
# Node 2683 in-degree: 3
# Node 2684 in-degree: 1
# Node 2685 in-degree: 2
# Node 2686 in-degree: 1
# Node 2687 in-degree: 2
# Node 2688 in-degree: 2
# Node 2689 in-degree: 1
# Node 2690 in-degree: 2
# Node 2691 in-degree: 5
# Node 2692 in-degree: 1
# Node 2693 in-degree: 2
# Node 2694 in-degree: 2
# Node 2695 in-degree: 3
# Node 2696 in-degree: 1
# Node 2697 in-degree: 1
# Node 2698 in-degree: 1
# Node 2699 in-degree: 1
# Node 2700 in-degree: 1
# Node 2701 in-degree: 1
# Node 2702 in-degree: 1
# Node 2703 in-degree: 1
# Node 2704 in-degree: 1
# Node 2705 in-degree: 1
# Node 2706 in-degree: 1
# Node 2707 in-degree: 1
# Node 2708 in-degree: 1
# Node 2709 in-degree: 1
# Node 2710 in-degree: 1
# Node 2711 in-degree: 1
# Node 2712 in-degree: 1
# Node 2713 in-degree: 1
# Node 2714 in-degree: 1
# Node 2715 in-degree: 1
# Node 2716 in-degree: 1
# Node 2717 in-degree: 1
# Node 2718 in-degree: 1
# Node 2719 in-degree: 1
# Node 2720 in-degree: 1
# Node 2721 in-degree: 1
# Node 2722 in-degree: 1
# Node 2723 in-degree: 1
# Node 2724 in-degree: 1
# Node 2725 in-degree: 1
# Node 2726 in-degree: 1
# Node 2727 in-degree: 1
# Node 2728 in-degree: 1
# Node 2729 in-degree: 1
# Node 2730 in-degree: 1
# Node 2731 in-degree: 1
# Node 2732 in-degree: 1
# Node 2733 in-degree: 1
# Node 2734 in-degree: 1
# Node 2735 in-degree: 1
# Node 2736 in-degree: 1
# Node 2737 in-degree: 1
# Node 2738 in-degree: 1
# Node 2739 in-degree: 1
# Node 2740 in-degree: 1
# Node 2741 in-degree: 1
# Node 2742 in-degree: 4
# Node 2743 in-degree: 1
# Node 2744 in-degree: 3
# Node 2745 in-degree: 1
# Node 2746 in-degree: 1
# Node 2747 in-degree: 1
# Node 2748 in-degree: 2
# Node 2749 in-degree: 4
# Node 2750 in-degree: 4
# Node 2751 in-degree: 3
# Node 2752 in-degree: 1
# Node 2753 in-degree: 1
# Node 2754 in-degree: 1
# Node 2755 in-degree: 1
# Node 2756 in-degree: 1
# Node 2757 in-degree: 1
# Node 2758 in-degree: 1
# Node 2759 in-degree: 1
# Node 2760 in-degree: 1
# Node 2761 in-degree: 1
# Node 2762 in-degree: 1
# Node 2763 in-degree: 1
# Node 2764 in-degree: 1
# Node 2765 in-degree: 1
# Node 2766 in-degree: 1
# Node 2767 in-degree: 1
# Node 2768 in-degree: 1
# Node 2769 in-degree: 1
# Node 2770 in-degree: 1
# Node 2771 in-degree: 1
# Node 2772 in-degree: 1
# Node 2773 in-degree: 1
# Node 2774 in-degree: 1
# Node 2775 in-degree: 1
# Node 2776 in-degree: 1
# Node 2777 in-degree: 2
# Node 2778 in-degree: 1
# Node 2779 in-degree: 1
# Node 2780 in-degree: 1
# Node 2781 in-degree: 1
# Node 2782 in-degree: 1
# Node 2783 in-degree: 1
# Node 2784 in-degree: 1
# Node 2785 in-degree: 1
# Node 2786 in-degree: 1
# Node 2787 in-degree: 1
# Node 2788 in-degree: 1
# Node 2789 in-degree: 1
# Node 2790 in-degree: 1
# Node 2791 in-degree: 1
# Node 2792 in-degree: 1
# Node 2793 in-degree: 1
# Node 2794 in-degree: 2
# Node 2795 in-degree: 3
# Node 2796 in-degree: 1
# Node 2797 in-degree: 1
# Node 2798 in-degree: 1
# Node 2799 in-degree: 1
# Node 2800 in-degree: 1
# Node 2801 in-degree: 1
# Node 2802 in-degree: 1
# Node 2803 in-degree: 1
# Node 2804 in-degree: 1
# Node 2805 in-degree: 1
# Node 2806 in-degree: 1
# Node 2807 in-degree: 1
# Node 2808 in-degree: 1
# Node 2809 in-degree: 1
# Node 2810 in-degree: 3
# Node 2811 in-degree: 1
# Node 2812 in-degree: 1
# Node 2813 in-degree: 1
# Node 2814 in-degree: 1
# Node 2815 in-degree: 1
# Node 2816 in-degree: 1
# Node 2817 in-degree: 1
# Node 2818 in-degree: 1
# Node 2819 in-degree: 1
# Node 2820 in-degree: 1
# Node 2821 in-degree: 1
# Node 2822 in-degree: 1
# Node 2823 in-degree: 1
# Node 2824 in-degree: 1
# Node 2825 in-degree: 1
# Node 2826 in-degree: 1
# Node 2827 in-degree: 1
# Node 2828 in-degree: 1
# Node 2829 in-degree: 1
# Node 2830 in-degree: 1
# Node 2831 in-degree: 1
# Node 2832 in-degree: 1
# Node 2833 in-degree: 1
# Node 2834 in-degree: 1
# Node 2835 in-degree: 1
# Node 2836 in-degree: 1
# Node 2837 in-degree: 1
# Node 2838 in-degree: 1
# Node 2839 in-degree: 1
# Node 2840 in-degree: 1
# Node 2841 in-degree: 1
# Node 2842 in-degree: 1
# Node 2843 in-degree: 1
# Node 2844 in-degree: 1
# Node 2845 in-degree: 1
# Node 2846 in-degree: 1
# Node 2847 in-degree: 1
# Node 2848 in-degree: 1
# Node 2849 in-degree: 1
# Node 2850 in-degree: 1
# Node 2851 in-degree: 1
# Node 2852 in-degree: 1
# Node 2853 in-degree: 1
# Node 2854 in-degree: 1
# Node 2855 in-degree: 1
# Node 2856 in-degree: 1
# Node 2857 in-degree: 1
# Node 2858 in-degree: 2
# Node 2859 in-degree: 1
# Node 2860 in-degree: 1
# Node 2861 in-degree: 2
# Node 2862 in-degree: 1
# Node 2863 in-degree: 5
# Node 2864 in-degree: 4
# Node 2865 in-degree: 2
# Node 2866 in-degree: 1
# Node 2867 in-degree: 1
# Node 2868 in-degree: 1
# Node 2869 in-degree: 4
# Node 2870 in-degree: 1
# Node 2871 in-degree: 3
# Node 2872 in-degree: 1
# Node 2873 in-degree: 2
# Node 2874 in-degree: 1
# Node 2875 in-degree: 1
# Node 2876 in-degree: 1
# Node 2877 in-degree: 2
# Node 2878 in-degree: 1
# Node 2879 in-degree: 2
# Node 2880 in-degree: 1
# Node 2881 in-degree: 2
# Node 2882 in-degree: 1
# Node 2883 in-degree: 1
# Node 2884 in-degree: 1
# Node 2885 in-degree: 2
# Node 2886 in-degree: 1
# Node 2887 in-degree: 1
# Node 2888 in-degree: 1
# Node 2889 in-degree: 1
# Node 2890 in-degree: 1
# Node 2891 in-degree: 2
# Node 2892 in-degree: 2
# Node 2893 in-degree: 1
# Node 2894 in-degree: 1
# Node 2895 in-degree: 2
# Node 2896 in-degree: 1
# Node 2897 in-degree: 1
# Node 2898 in-degree: 1
# Node 2899 in-degree: 1
# Node 2900 in-degree: 1
# Node 2901 in-degree: 1
# Node 2902 in-degree: 1
# Node 2903 in-degree: 1
# Node 2904 in-degree: 1
# Node 2905 in-degree: 1
# Node 2906 in-degree: 1
# Node 2907 in-degree: 1
# Node 2908 in-degree: 1
# Node 2909 in-degree: 1
# Node 2910 in-degree: 1
# Node 2911 in-degree: 1
# Node 2912 in-degree: 1
# Node 2913 in-degree: 1
# Node 2914 in-degree: 1
# Node 2915 in-degree: 1
# Node 2916 in-degree: 1
# Node 2917 in-degree: 1
# Node 2918 in-degree: 1
# Node 2919 in-degree: 1
# Node 2920 in-degree: 1
# Node 2921 in-degree: 1
# Node 2922 in-degree: 1
# Node 2923 in-degree: 1
# Node 2924 in-degree: 1
# Node 2925 in-degree: 1
# Node 2926 in-degree: 1
# Node 2927 in-degree: 1
# Node 2928 in-degree: 1
# Node 2929 in-degree: 1
# Node 2930 in-degree: 1
# Node 2931 in-degree: 1
# Node 2932 in-degree: 1
# Node 2933 in-degree: 1
# Node 2934 in-degree: 1
# Node 2935 in-degree: 4
# Node 2936 in-degree: 1
# Node 2937 in-degree: 2
# Node 2938 in-degree: 1
# Node 2939 in-degree: 1
# Node 2940 in-degree: 1
# Node 2941 in-degree: 1
# Node 2942 in-degree: 1
# Node 2943 in-degree: 1
# Node 2944 in-degree: 1
# Node 2945 in-degree: 1
# Node 2946 in-degree: 1
# Node 2947 in-degree: 1
# Node 2948 in-degree: 1
# Node 2949 in-degree: 1
# Node 2950 in-degree: 1
# Node 2951 in-degree: 1
# Node 2952 in-degree: 1
# Node 2953 in-degree: 1
# Node 2954 in-degree: 1
# Node 2955 in-degree: 1
# Node 2956 in-degree: 1
# Node 2957 in-degree: 2
# Node 2958 in-degree: 1
# Node 2959 in-degree: 1
# Node 2960 in-degree: 2
# Node 2961 in-degree: 1
# Node 2962 in-degree: 1
# Node 2963 in-degree: 2
# Node 2964 in-degree: 3
# Node 2965 in-degree: 1
# Node 2966 in-degree: 1
# Node 2967 in-degree: 1
# Node 2968 in-degree: 1
# Node 2969 in-degree: 1
# Node 2970 in-degree: 3
# Node 2971 in-degree: 1
# Node 2972 in-degree: 1
# Node 2973 in-degree: 1
# Node 2974 in-degree: 3
# Node 2975 in-degree: 3
# Node 2976 in-degree: 2
# Node 2977 in-degree: 1
# Node 2978 in-degree: 1
# Node 2979 in-degree: 1
# Node 2980 in-degree: 1
# Node 2981 in-degree: 1
# Node 2982 in-degree: 1
# Node 2983 in-degree: 1
# Node 2984 in-degree: 1
# Node 2985 in-degree: 1
# Node 2986 in-degree: 2
# Node 2987 in-degree: 1
# Node 2988 in-degree: 1
# Node 2989 in-degree: 1
# Node 2990 in-degree: 1
# Node 2991 in-degree: 1
# Node 2992 in-degree: 1
# Node 2993 in-degree: 1
# Node 2994 in-degree: 1
# Node 2995 in-degree: 2
# Node 2996 in-degree: 3
# Node 2997 in-degree: 1
# Node 2998 in-degree: 2
# Node 2999 in-degree: 1
# Node 3000 in-degree: 1
# Node 3001 in-degree: 2
# Node 3002 in-degree: 3
# Node 3003 in-degree: 1
# Node 3004 in-degree: 1
# Node 3005 in-degree: 1
# Node 3006 in-degree: 1
# Node 3007 in-degree: 1
# Node 3008 in-degree: 1
# Node 3009 in-degree: 1
# Node 3010 in-degree: 2
# Node 3011 in-degree: 1
# Node 3012 in-degree: 1
# Node 3013 in-degree: 1
# Node 3014 in-degree: 1
# Node 3015 in-degree: 1
# Node 3016 in-degree: 1
# Node 3017 in-degree: 1
# Node 3018 in-degree: 1
# Node 3019 in-degree: 3
# Node 3020 in-degree: 1
# Node 3021 in-degree: 1
# Node 3022 in-degree: 1
# Node 3023 in-degree: 2
# Node 3024 in-degree: 1
# Node 3025 in-degree: 1

# %% [markdown]
# # 建模

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import dgl
import dgl.nn as dglnn

# 定义 GCN 模型
class GCN(nn.Module):
    def __init__(self, in_feats, hidden_feats, out_feats):
        super(GCN, self).__init__()
        # 图卷积层（减少了卷积层的数量）
        self.conv1 = dglnn.GraphConv(in_feats, hidden_feats, allow_zero_in_degree=True)
        self.conv2 = dglnn.GraphConv(hidden_feats, out_feats, allow_zero_in_degree=True)

    def forward(self, g, features):
        # 第一层图卷积
        h = self.conv1(g, features)
        h = F.relu(h)
        # 第二层图卷积
        h = self.conv2(g, h)
        return h

# 参数设置
in_feats = 2  # 输入特征维度（c_entry_code 和 kinships 数量）
hidden_feats = 8  # 减小隐藏层特征维度
out_feats = 2  # 输出类别数（这里是2，假设是二分类任务）

# 实例化模型
model = GCN(in_feats, hidden_feats, out_feats)

# 选择优化器
optimizer = torch.optim.Adam(model.parameters(), lr=0.005)  # 使用较低的学习率

# 准备数据
features = torch.cat((g.ndata['entry_code_feat'], g.ndata['kinship_count_feat']), dim=1)  # 合并两个特征
labels = g.ndata['label']  # 节点标签

# 将数据集划分为训练集和测试集
train_mask = torch.randint(0, 2, (g.num_nodes(),)).bool()  # 随机划分训练数据
train_labels = labels[train_mask]  # 训练标签
train_features = features[train_mask]  # 训练特征

# 训练模型
num_epochs = 100
for epoch in range(num_epochs):
    model.train()
    optimizer.zero_grad()

    # 前向传播
    logits = model(g, features)
    
    # 计算损失（这里使用交叉熵损失）
    loss = F.cross_entropy(logits[train_mask], train_labels)
    loss.backward()
    optimizer.step()

    # 输出每轮的损失
    if epoch % 10 == 0:
        print(f"Epoch {epoch}, Loss: {loss.item()}")

# 模型评估
model.eval()
with torch.no_grad():
    logits = model(g, features)
    pred = logits.argmax(dim=1)  # 预测标签
    print("Prediction:", pred)

# 输出模型的基本信息
print("Number of nodes in the graph:", g.num_nodes())
print("Number of edges in the graph:", g.num_edges())
# Out:
# Epoch 0, Loss: 0.8521443605422974
# Epoch 10, Loss: 0.7005615234375
# Epoch 20, Loss: 0.58443683385849
# Epoch 30, Loss: 0.4937404692173004
# Epoch 40, Loss: 0.4229623079299927
# Epoch 50, Loss: 0.36897483468055725
# Epoch 60, Loss: 0.3282005190849304
# Epoch 70, Loss: 0.29684504866600037
# Epoch 80, Loss: 0.27157503366470337
# Epoch 90, Loss: 0.2509623169898987
# Prediction: tensor([0, 0, 0,  ..., 0, 0, 0])
# Number of nodes in the graph: 3026
# Number of edges in the graph: 3017

# %%
# 后
import torch
import torch.nn as nn
import torch.nn.functional as F
import dgl
import dgl.nn as dglnn

# 定义 GCN 模型
class GCN(nn.Module):
    def __init__(self, in_feats, hidden_feats, out_feats, dropout_rate=0.5):
        super(GCN, self).__init__()
        # 图卷积层
        self.conv1 = dglnn.GraphConv(in_feats, hidden_feats, allow_zero_in_degree=True)
        self.conv2 = dglnn.GraphConv(hidden_feats, hidden_feats, allow_zero_in_degree=True)  # 增加额外的卷积层
        self.conv3 = dglnn.GraphConv(hidden_feats, out_feats, allow_zero_in_degree=True)  # 输出层

        # Dropout 层
        self.dropout = nn.Dropout(dropout_rate)

    def forward(self, g, features):
        # 第一层图卷积
        h = self.conv1(g, features)
        h = F.relu(h)
        h = self.dropout(h)  # 使用 Dropout 防止过拟合

        # 第二层图卷积
        h = self.conv2(g, h)
        h = F.relu(h)
        h = self.dropout(h)

        # 第三层图卷积（输出层）
        h = self.conv3(g, h)
        return h

# 参数设置
in_feats = 2  # 输入特征维度（c_entry_code 和 kinships 数量）
hidden_feats = 64  # 增加隐藏层特征维度
out_feats = 2  # 输出类别数（这里是2，假设是二分类任务）
dropout_rate = 0.5  # Dropout rate 用于防止过拟合

# 实例化模型
model = GCN(in_feats, hidden_feats, out_feats, dropout_rate)

# 选择优化器
optimizer = torch.optim.Adam(model.parameters(), lr=0.01)

# 准备数据
features = torch.cat((g.ndata['entry_code_feat'], g.ndata['kinship_count_feat']), dim=1)  # 合并两个特征
labels = g.ndata['label']  # 节点标签

# 将数据集划分为训练集和测试集
train_mask = torch.randint(0, 2, (g.num_nodes(),)).bool()  # 随机划分训练数据
train_labels = labels[train_mask]  # 训练标签
train_features = features[train_mask]  # 训练特征

# 训练模型
num_epochs = 100
for epoch in range(num_epochs):
    model.train()
    optimizer.zero_grad()

    # 前向传播
    logits = model(g, features)
    
    # 计算损失（这里使用交叉熵损失）
    loss = F.cross_entropy(logits[train_mask], train_labels)
    loss.backward()
    optimizer.step()

    # 输出每轮的损失
    if epoch % 10 == 0:
        print(f"Epoch {epoch}, Loss: {loss.item()}")

# 模型评估
model.eval()
with torch.no_grad():
    logits = model(g, features)
    pred = logits.argmax(dim=1)  # 预测标签
    print("Prediction:", pred)

# 输出模型的基本信息
print("Number of nodes in the graph:", g.num_nodes())
print("Number of edges in the graph:", g.num_edges())
# Out:
# Epoch 0, Loss: 0.7449072003364563
# Epoch 10, Loss: 0.33872780203819275
# Epoch 20, Loss: 0.3258473873138428
# Epoch 30, Loss: 0.29640933871269226
# Epoch 40, Loss: 0.2737480700016022
# Epoch 50, Loss: 0.25876787304878235
# Epoch 60, Loss: 0.24943949282169342
# Epoch 70, Loss: 0.24209658801555634
# Epoch 80, Loss: 0.23722277581691742
# Epoch 90, Loss: 0.2329998016357422
# Prediction: tensor([0, 0, 0,  ..., 0, 0, 0])
# Number of nodes in the graph: 58726
# Number of edges in the graph: 103970

# %% [markdown]
# # 验证结果

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, ConfusionMatrixDisplay, roc_curve, auc

# 设置模型为评估模式
model.eval()
with torch.no_grad():
    logits = model(g, features)  # 模型输出
    pred = logits.argmax(dim=1)  # 预测标签

    # 计算各项指标
    accuracy = accuracy_score(labels.numpy(), pred.numpy())
    precision = precision_score(labels.numpy(), pred.numpy(), average='binary')
    recall = recall_score(labels.numpy(), pred.numpy(), average='binary')
    f1 = f1_score(labels.numpy(), pred.numpy(), average='binary')
    conf_matrix = confusion_matrix(labels.numpy(), pred.numpy())

    # 获取 ROC 曲线和 AUC
    probs = logits[:, 1].numpy()  # 获取属于类别 1（入仕）的概率
    fpr, tpr, thresholds = roc_curve(labels.numpy(), probs)
    roc_auc = auc(fpr, tpr)

# 打印评估指标
print(f"Test Accuracy: {accuracy * 100:.2f}%")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1 Score: {f1:.4f}")
print("Confusion Matrix:")
print(conf_matrix)

# 可视化混淆矩阵
plt.figure(figsize=(6, 6))
disp = ConfusionMatrixDisplay(confusion_matrix=conf_matrix, display_labels=["not an official", "official"])
disp.plot(cmap=plt.cm.Blues, values_format="d", ax=plt.gca())
plt.title("Confusion Matrix")
plt.show()

# 绘制 ROC 曲线
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='blue', lw=2, label=f"AUC = {roc_auc:.2f}")
plt.plot([0, 1], [0, 1], color='gray', linestyle='--', lw=1)  # 随机分类参考线
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve")
plt.legend(loc="lower right")
plt.grid(alpha=0.4)
plt.show()
# Out:
# Test Accuracy: 92.99%
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# Confusion Matrix:
# [[2814    0]
#  [ 212    0]]
# D:\miniconda\envs\SDSC5002\lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
